# %%
import re
import requests
import requests_html
import string
import pandas as pd

# %%
CATEGORY = 'Category:Hindi_terms_with_IPA_pronunciation'
LIMIT = 500    #number of vocab or 'TITLE'
INITIAL_QUERY = f'https://en.wiktionary.org/w/api.php?action=query&format=json&list=categorymembers&cmtitle={CATEGORY}&cmlimit={LIMIT}'
CONTINUE_TEMPLATE = string.Template(INITIAL_QUERY + "&cmcontinue=$cmcontinue")

PAGE_TEMPLATE = string.Template("https://en.wiktionary.org/wiki/$word")     # $_ -> placeholder for values of a dictionary. Template class of string library.

LI_SELECTOR = '//li[sup[a[@title = "Appendix:Hindi pronunciation"]] and span[@class = "IPA"]]' #language specific
SPAN_SELECTOR = '//span[@class = "IPA"]'       # what is this 'span' doing? 
PHONEMES = r"/(.+?)/"   #language specific

# %%
def _yield_phn(request):
    for li in request.html.xpath(LI_SELECTOR):
        for span in li.xpath(SPAN_SELECTOR):
            m = re.search(PHONEMES, span.text)
            print(m)
            if m:
                yield m

# %%
def _print_data(data):
    session = requests_html.HTMLSession()
    """" <example of data>
query":{"categorymembers":[{"pageid":81811,"ns":0,"title":"Homo sapiens"},
{"pageid":3072481,"ns":0,"title":"\u0901"}...."""
    
    for member in data["query"]["categorymembers"]:
        word = member["title"]   
        # Skips multiword examples.
        if " " in word:
            continue
        query = PAGE_TEMPLATE.substitute(word=word)
        request = session.get(query)  #Grab a list of all links on the page
        print(request)
        for m in _yield_phn(request):
            pron = m.group(1)   #IPA without //. m.group(0) =  /IPA/ 
            print(f"{word}\t{pron}")

# %%
def main():
    data = requests.get(INITIAL_QUERY).json() #In case the JSON decoding fails, r.json() raises an exception
    _print_data(data)
    code = data["continue"]["cmcontinue"]     # next page's number 
    """ <example>
    continue":{"cmcontinue":"page|414245494c4c45204d4552450a414245494c4c45204dc3885245|6478110","continue":"-||"}
    """ 
    next_query = CONTINUE_TEMPLATE.substitute(cmcontinue=code)
    while True:
        
        data = requests.get(next_query).json()
        _print_data(data)
        # Then this is the last one.
        
        if not "continue" in data:
            break
        code = data["continue"]["cmcontinue"]    #assign a new next page's number to code
        next_query = CONTINUE_TEMPLATE.substitute(cmcontinue=code)
        
if __name__ == "__main__":
    main()

# %%
data = requests.get(INITIAL_QUERY).json()

# %%
_print_data(data)
# Out:
# <Response [200]>
# None
# <Response [200]>
# None
# None
# None
# None
# None
# <Response [200]>
# <_sre.SRE_Match object; span=(0, 3), match='/ə/'>
# <Response [200]>
# <_sre.SRE_Match object; span=(0, 4), match='/ə̃/'>
# <Response [200]>
# <_sre.SRE_Match object; span=(0, 13), match='/ə̃ɡ.ɾeː.ziː/'>
# <Response [200]>
# <_sre.SRE_Match object; span=(0, 9), match='/ə̃ʈ.nɑː/'>
# <Response [200]>
# <_sre.SRE_Match object; span=(0, 4), match='/ə̃/'>
# <Response [200]>
# <_sre.SRE_Match object; span=(0, 5), match='/əŋk/'>
# <Response [200]>
# <_sre.SRE_Match object; span=(0, 8), match='/əŋ.kən/'>
# <Response [200]>
# <_sre.SRE_Match object; span=(0, 8), match='/əŋ.kəl/'>
# <Response [200]>
# <_sre.SRE_Match object; span=(0, 9), match='/əŋ.kɪt̪/'>
# <Response [200]>
# <_sre.SRE_Match object; span=(0, 8), match='/əŋ.kʊɾ/'>
# <Response [200]>
# <_sre.SRE_Match object; span=(0, 12), match='/əŋ.kʊ.ɾɪt̪/'>
# <Response [200]>
# <_sre.SRE_Match object; span=(0, 8), match='/əŋ.kʊʃ/'>
# <Response [200]>
# <_sre.SRE_Match object; span=(0, 5), match='/əŋɡ/'>
# <Response [200]>
# <_sre.SRE_Match object; span=(0, 19), match='/əŋ.ɡət͡ʃ.t͡ʃʰeːd̪/'>
# <Response [200]>
# <_sre.SRE_Match object; span=(0, 11), match='/əŋɡ.ɽɑːiː/'>
# <Response [200]>
# <_sre.SRE_Match object; span=(0, 11), match='/əŋɡ.d̪ɑːn/'>
# <Response [200]>
# <_sre.SRE_Match object; span=(0, 11), match='/əŋ.ɡə.nɑː/'>
# <Response [200]>
# <_sre.SRE_Match object; span=(0, 10), match='/əŋ.ɡʱiːn/'>
# <Response [200]>
# <_sre.SRE_Match object; span=(0, 9), match='/əŋ.ɡɑːɾ/'>
# <Response [200]>
# <_sre.SRE_Match object; span=(0, 12), match='/əŋ.ɡɑː.ɾɑː/'>
# <Response [200]>
# <_sre.SRE_Match object; span=(0, 12), match='/əŋ.ɡiː.jɑː/'>
# <Response [200]>
# <_sre.SRE_Match object; span=(0, 13), match='/əŋ.ɡiː.ʈʰiː/'>
# <Response [200]>
# <_sre.SRE_Match object; span=(0, 8), match='/əŋ.ɡʊl/'>
# <Response [200]>
# <_sre.SRE_Match object; span=(0, 11), match='/əŋ.ɡʊ.liː/'>
# <Response [200]>
# <_sre.SRE_Match object; span=(0, 13), match='/əŋ.ɡuː.ʈʰɑː/'>
# <Response [200]>
# <_sre.SRE_Match object; span=(0, 9), match='/əŋ.ɡuːɾ/'>
# <Response [200]>
# <_sre.SRE_Match object; span=(0, 15), match='/əŋ.ɡoː.t͡ʃʰɑː/'>
# <Response [200]>
# <_sre.SRE_Match object; span=(0, 9), match='/əŋ.ɡoːʈ/'>
# <Response [200]>
# <_sre.SRE_Match object; span=(0, 10), match='/əŋɡ.ɾeːz/'>
# <Response [200]>
# <_sre.SRE_Match object; span=(0, 18), match='/əŋɡ.ɾeː.ziː.jət̪/'>
# <Response [200]>
# <_sre.SRE_Match object; span=(0, 13), match='/əŋɡ.ɾeː.ziː/'>
# <Response [200]>
# <_sre.SRE_Match object; span=(0, 15), match='/əŋɡ.ɾeː.d͡ʒiː/'>
# <Response [200]>
# <_sre.SRE_Match object; span=(0, 10), match='/əɲ.t͡ʃəl/'>
# <Response [200]>
# <_sre.SRE_Match object; span=(0, 11), match='/əɲ.t͡ʃʰəɾ/'>
# <Response [200]>
# <_sre.SRE_Match object; span=(0, 10), match='/əɲ.d͡ʒən/'>
# <Response [200]>
# <_sre.SRE_Match object; span=(0, 11), match='/əɲ.d͡ʒɑːm/'>
# <Response [200]>
# <_sre.SRE_Match object; span=(0, 11), match='/əɲ.d͡ʒiːɾ/'>
# <Response [200]>
# <_sre.SRE_Match object; span=(0, 10), match='/əɲ.d͡ʒuː/'>
# <Response [200]>
# <_sre.SRE_Match object; span=(0, 10), match='/ənʈ.sənʈ/'>
# <Response [200]>
# <_sre.SRE_Match object; span=(0, 19), match='/ən.ʈɑːɾ.kə.ʈɪ.kɑː/'>
# <Response [200]>
# None
# <Response [200]>
# <_sre.SRE_Match object; span=(0, 8), match='/ən.ɖɑː/'>
# <Response [200]>
# <_sre.SRE_Match object; span=(0, 12), match='/ən.ɖoː.ɾɑː/'>
# <Response [200]>
# <_sre.SRE_Match object; span=(0, 6), match='/ənt̪/'>
# <Response [200]>
# <_sre.SRE_Match object; span=(0, 15), match='/ən.t̪əʰk.ʃeːp/'>
# <Response [200]>
# <_sre.SRE_Match object; span=(0, 10), match='/ənt̪.ɽiː/'>
# <Response [200]>
# <_sre.SRE_Match object; span=(0, 18), match='/ən.t̪ə.ɾəŋɡ.t̪ɑː/'>
# <Response [200]>
# <_sre.SRE_Match object; span=(0, 16), match='/ən.t̪əɾ.d͡ʒɑːl/'>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <_sre.SRE_Match object; span=(0, 27), match='/ən.t̪əɾ.ɾɑːʃʈ.ɾiː.jə.t̪ɑː/'>
# <Response [200]>
# <_sre.SRE_Match object; span=(0, 10), match='/ənt̪.ɾɑː/'>
# <_sre.SRE_Match object; span=(0, 12), match='/ən.t̪ə.ɾɑː/'>
# <Response [200]>
# <_sre.SRE_Match object; span=(0, 13), match='/ən.t̪ə.ɾɑːl/'>
# <Response [200]>
# <_sre.SRE_Match object; span=(0, 11), match='/ənt̪.ɾɪkʃ/'>
# <Response [200]>
# <_sre.SRE_Match object; span=(0, 10), match='/ənt̪.ɾɪm/'>
# <Response [200]>
# <_sre.SRE_Match object; span=(0, 14), match='/ən.t̪əɾ.ɡət̪/'>
# <Response [200]>
# <_sre.SRE_Match object; span=(0, 21), match='/ən.t̪əɾ.d͡ʒɑː.t̪iːj/'>
# <Response [200]>
# <_sre.SRE_Match object; span=(0, 16), match='/ən.t̪əɾ.d͡ʒɑːl/'>
# <Response [200]>
# <_sre.SRE_Match object; span=(0, 19), match='/ən.t̪əɾ.d̪eː.ʃiːj/'>
# <Response [200]>
# <_sre.SRE_Match object; span=(0, 17), match='/ən.t̪əɾ.nɪ.ɦɪt̪/'>
# <Response [200]>
# <_sre.SRE_Match object; span=(0, 20), match='/ən.t̪əɾ.ɾɑːʃʈ.ɾiːj/'>
# <Response [200]>
# <_sre.SRE_Match object; span=(0, 17), match='/ən.t̪əɾ.ʋɑː.siː/'>
# <Response [200]>
# <_sre.SRE_Match object; span=(0, 17), match='/ən.t̪ɑːk.ʃə.ɾiː/'>
# <Response [200]>
# <_sre.SRE_Match object; span=(0, 9), match='/ən.t̪ɪm/'>
# <Response [200]>
# <_sre.SRE_Match object; span=(0, 15), match='/ənt̪.jeːʃ.ʈiː/'>
# <Response [200]>
# <_sre.SRE_Match object; span=(0, 9), match='/ən.d̪əɾ/'>
# <Response [200]>
# <_sre.SRE_Match object; span=(0, 10), match='/ən̪ˈd̪az/'>
# None
# <Response [200]>
# None
# <Response [200]>
# <_sre.SRE_Match object; span=(0, 10), match='/ən.d̪ʱəɽ/'>
# <Response [200]>
# <_sre.SRE_Match object; span=(0, 16), match='/ənd̪ʱ.ʋɪʃ.ʋɑːs/'>
# <Response [200]>
# <_sre.SRE_Match object; span=(0, 19), match='/ən.d̪ʱɑː.d̪ʱʊnd̪ʱ/'>
# <Response [200]>
# <_sre.SRE_Match object; span=(0, 14), match='/ən.d̪ʱeː.ɾɑː/'>
# <Response [200]>
# <_sre.SRE_Match object; span=(0, 8), match='/əm.bəɾ/'>
# <Response [200]>
# <_sre.SRE_Match object; span=(0, 5), match='/ənʃ/'>
# <Response [200]>
# <_sre.SRE_Match object; span=(0, 13), match='/ənʃ.kɑː.lɪk/'>
# <Response [200]>
# <_sre.SRE_Match object; span=(0, 10), match='/ənʃ.t̪əʰ/'>
# <Response [200]>
# <_sre.SRE_Match object; span=(0, 4), match='/əʰ/'>
# <Response [200]>
# <_sre.SRE_Match object; span=(0, 7), match='/ə.kəɽ/'>
# <Response [200]>
# <_sre.SRE_Match object; span=(0, 8), match='/ə.kəɾm/'>
# <Response [200]>
# <_sre.SRE_Match object; span=(0, 19), match='/ə.kəɾ.mən.jə.t̪ɑː/'>
# <Response [200]>
# <_sre.SRE_Match object; span=(0, 13), match='/ə.kəs.mɑːt̪/'>
# <Response [200]>
# <_sre.SRE_Match object; span=(0, 5), match='/əkl/'>
# <_sre.SRE_Match object; span=(0, 5), match='/əql/'>
# <_sre.SRE_Match object; span=(0, 7), match='/ə.kəl/'>
# <_sre.SRE_Match object; span=(0, 7), match='/ə.qəl/'>
# <Response [200]>
# <_sre.SRE_Match object; span=(0, 13), match='/ə.kəl.mənd̪/'>
# <_sre.SRE_Match object; span=(0, 13), match='/ə.qəl.mənd̪/'>
# <_sre.SRE_Match object; span=(0, 11), match='/əkl.mənd̪/'>
# <_sre.SRE_Match object; span=(0, 11), match='/əql.mənd̪/'>
# <Response [200]>
# <_sre.SRE_Match object; span=(0, 10), match='/ə.kɑːd͡ʒ/'>
# <Response [200]>
# <_sre.SRE_Match object; span=(0, 13), match='/ə.kɑːd̪.mɪk/'>
# <Response [200]>
# <_sre.SRE_Match object; span=(0, 13), match='/ə.kɑːd̪.miː/'>
# <Response [200]>
# <_sre.SRE_Match object; span=(0, 11), match='/ə.kɑː.ɾən/'>
# <Response [200]>
# <_sre.SRE_Match object; span=(0, 13), match='/ə.kɑː.ɾət̪ʰ/'>
# <Response [200]>
# <_sre.SRE_Match object; span=(0, 8), match='/ə.kɑːl/'>
# <Response [200]>
# <_sre.SRE_Match object; span=(0, 9), match='/ə.kuːt̪/'>
# <Response [200]>
# <_sre.SRE_Match object; span=(0, 11), match='/ə.keː.lɑː/'>
# <Response [200]>
# <_sre.SRE_Match object; span=(0, 15), match='/ə.keː.lɑː.pən/'>
# <Response [200]>
# <_sre.SRE_Match object; span=(0, 9), match='/ək.kʰəɽ/'>
# <Response [200]>
# <_sre.SRE_Match object; span=(0, 9), match='/ək.kʰɑː/'>
# <Response [200]>
# <_sre.SRE_Match object; span=(0, 12), match='/ək.ʈuː.bəɾ/'>
# <Response [200]>
# <_sre.SRE_Match object; span=(0, 13), match='/ək.t̪uː.bəɾ/'>
# <Response [200]>
# <_sre.SRE_Match object; span=(0, 9), match='/ək.ʃət̪/'>
# <Response [200]>
# <_sre.SRE_Match object; span=(0, 8), match='/əkˈʃəj/'>
# <_sre.SRE_Match object; span=(0, 7), match='/ˈəkʃɛ/'>
# <Response [200]>
# <_sre.SRE_Match object; span=(0, 17), match='/ək.ʃə.ɾɑː.ɾəmbʱ/'>
# <Response [200]>
# <_sre.SRE_Match object; span=(0, 5), match='/əks/'>
# <Response [200]>
# <_sre.SRE_Match object; span=(0, 8), match='/ək.səɾ/'>
# <Response [200]>
# <_sre.SRE_Match object; span=(0, 9), match='/ə.kʰəɳɖ/'>
# <Response [200]>
# <_sre.SRE_Match object; span=(0, 14), match='/ə.kʰənɖ.t̪ɑː/'>
# <Response [200]>
# <_sre.SRE_Match object; span=(0, 12), match='/ə.kʰəɾ.nɑː/'>
# <Response [200]>
# <_sre.SRE_Match object; span=(0, 10), match='/əkʰ.bɑːɾ/'>
# <_sre.SRE_Match object; span=(0, 9), match='/əx.bɑːɾ/'>
# <Response [200]>
# <_sre.SRE_Match object; span=(0, 18), match='/əkʰ.bɑːɾ.ʋɑː.lɑː/'>
# <_sre.SRE_Match object; span=(0, 17), match='/əx.bɑːɾ.ʋɑː.lɑː/'>
# <Response [200]>
# <_sre.SRE_Match object; span=(0, 10), match='/əkʰ.ɾoːʈ/'>
# <_sre.SRE_Match object; span=(0, 9), match='/əx.ɾoːʈ/'>
# <Response [200]>
# <_sre.SRE_Match object; span=(0, 12), match='/ə.kʰɑː.ɽɑː/'>
# <Response [200]>
# <_sre.SRE_Match object; span=(0, 8), match='/ə.kʰɪl/'>
# <Response [200]>
# <_sre.SRE_Match object; span=(0, 11), match='/ə.ɡə.nɪt̪/'>
# <Response [200]>
# <_sre.SRE_Match object; span=(0, 7), match='/ə.ɡəɾ/'>
# <Response [200]>
# <_sre.SRE_Match object; span=(0, 13), match='/ə.ɡəɾ.t͡ʃeː/'>
# <Response [200]>
# <_sre.SRE_Match object; span=(0, 15), match='/ə.ɡəɾ.t̪ə.lɑː/'>
# <Response [200]>
# <_sre.SRE_Match object; span=(0, 17), match='/ə.ɡəɾ.bət̪.t̪iː/'>
# <Response [200]>
# <_sre.SRE_Match object; span=(0, 8), match='/əɡ.lɑː/'>
# <Response [200]>
# <_sre.SRE_Match object; span=(0, 9), match='/ə.ɡəst̪/'>
# <Response [200]>
# <_sre.SRE_Match object; span=(0, 7), match='/ə.ɡɪn/'>
# <Response [200]>
# <_sre.SRE_Match object; span=(0, 8), match='/ə.ɡʊɑː/'>
# <Response [200]>
# <_sre.SRE_Match object; span=(0, 8), match='/əɡ.niː/'>
# <Response [200]>
# <_sre.SRE_Match object; span=(0, 19), match='/əɡ.nɪ.pə.ɾiːk.ʃɑː/'>
# <Response [200]>
# <_sre.SRE_Match object; span=(0, 15), match='/əɡ.nɪ.ʃɑː.mək/'>
# <Response [200]>
# <_sre.SRE_Match object; span=(0, 13), match='/əɡn.jɑː.ʃəj/'>
# <Response [200]>
# <_sre.SRE_Match object; span=(0, 10), match='/əɡ.ɾəd͡ʒ/'>
# <Response [200]>
# <_sre.SRE_Match object; span=(0, 8), match='/əɡ.ɾɪm/'>
# <Response [200]>
# <_sre.SRE_Match object; span=(0, 14), match='/ə.t͡ʃəm.bʱɑː/'>
# <Response [200]>
# <_sre.SRE_Match object; span=(0, 10), match='/ət͡ʃ.kən/'>
# <Response [200]>
# <_sre.SRE_Match object; span=(0, 9), match='/ə
/'>
# <Response [200]>
# <_sre.SRE_Match object; span=(0, 14), match='/əbʱ.jɑːs.ʋəʃ/'>
# <Response [200]>
# <_sre.SRE_Match object; span=(0, 9), match='/əbʱ.ɾək/'>
# <Response [200]>
# <_sre.SRE_Match object; span=(0, 7), match='/ə.mən/'>
# <Response [200]>
# <_sre.SRE_Match object; span=(0, 12), match='/əm.ɾiː.kɑː/'>
# <Response [200]>
# <_sre.SRE_Match object; span=(0, 10), match='/əm.ɾuːd̪/'>
# <Response [200]>
# <_sre.SRE_Match object; span=(0, 7), match='/ə.məl/'>
# <Response [200]>
# <_sre.SRE_Match object; span=(0, 8), match='/ə.miːɾ/'>
# <Response [200]>
# <_sre.SRE_Match object; span=(0, 14), match='/ə.meː.ɾɪ.kɑː/'>
# <Response [200]>
# <_sre.SRE_Match object; span=(0, 14), match='/ə.meː.ɾɪ.kiː/'>
# <Response [200]>
# <_sre.SRE_Match object; span=(0, 8), match='/əm.bəɾ/'>
# <Response [200]>
# <_sre.SRE_Match object; span=(0, 8), match='/əm.mɑː/'>
# <Response [200]>
# <_sre.SRE_Match object; span=(0, 9), match='/əm.mɑ̃ː/'>
# <Response [200]>
# <_sre.SRE_Match object; span=(0, 8), match='/əm.miː/'>
# <Response [200]>
# <_sre.SRE_Match object; span=(0, 5), match='/əml/'>
# <Response [200]>
# <_sre.SRE_Match object; span=(0, 10), match='/əml.t̪ɑː/'>
# <_sre.SRE_Match object; span=(0, 12), match='/əm.lə.t̪ɑː/'>
# <Response [200]>
# <_sre.SRE_Match object; span=(0, 12), match='/əml.pɪt̪t̪/'>
# <_sre.SRE_Match object; span=(0, 14), match='/əm.lə.pɪt̪t̪/'>
# <Response [200]>
# <_sre.SRE_Match object; span=(0, 9), match='/əm.liːj/'>
# <Response [200]>
# <_sre.SRE_Match object; span=(0, 7), match='/ə.jəs/'>
# <Response [200]>
# <_sre.SRE_Match object; span=(0, 8), match='/ə.jəsk/'>
# <Response [200]>
# <_sre.SRE_Match object; span=(0, 14), match='/ə.joːd̪ʱ.jɑː/'>
# <Response [200]>
# <_sre.SRE_Match object; span=(0, 14), match='/ə.ɾəkt̪.t̪ɑː/'>
# <Response [200]>
# <_sre.SRE_Match object; span=(0, 11), match='/ə.ɾəɡ.niː/'>
# <Response [200]>
# <_sre.SRE_Match object; span=(0, 7), match='/ə.ɾəb/'>
# <Response [200]>
# <_sre.SRE_Match object; span=(0, 10), match='/əɾ.bɪnd̪/'>
# <Response [200]>
# <_sre.SRE_Match object; span=(0, 9), match='/əɾ.mɑːn/'>
# <Response [200]>
# <_sre.SRE_Match object; span=(0, 10), match='/əɾ.ʋɪnd̪/'>
# <Response [200]>
# <_sre.SRE_Match object; span=(0, 12), match='/ə.ɾɪ.ɦənt̪/'>
# <Response [200]>
# <_sre.SRE_Match object; span=(0, 12), match='/ə.ɾʊ.t͡ʃiː/'>
# <Response [200]>
# <_sre.SRE_Match object; span=(0, 15), match='/ə.ɾʊ.noː.d̪əj/'>
# <Response [200]>
# <_sre.SRE_Match object; span=(0, 7), match='/ə.ɾeː/'>
# <Response [200]>
# <_sre.SRE_Match object; span=(0, 5), match='/əɾz/'>
# <Response [200]>
# <_sre.SRE_Match object; span=(0, 8), match='/əɾ.ziː/'>
# <Response [200]>
# <_sre.SRE_Match object; span=(0, 10), match='/əɾ.d͡ʒʊn/'>
# <Response [200]>
# <_sre.SRE_Match object; span=(0, 19), match='/əɾ.d͡ʒeːn.ʈiː.nɑː/'>
# <Response [200]>
# <_sre.SRE_Match object; span=(0, 8), match='/ˈəɾt̪ʰ/'>
# <Response [200]>
# <_sre.SRE_Match object; span=(0, 15), match='/əɾ.t̪ʰə.puːɾn/'>
# <Response [200]>
# <_sre.SRE_Match object; span=(0, 17), match='/əɾ.t̪ʰə.mɪ.t̪iː/'>
# <Response [200]>
# <_sre.SRE_Match object; span=(0, 23), match='/əɾ.t̪ʰəʋ.jə.ʋəs.t̪ʰɑː/'>
# <Response [200]>
# <_sre.SRE_Match object; span=(0, 20), match='/əɾ.t̪ʰə.ʃɑːst̪.ɾiː/'>
# <Response [200]>
# <_sre.SRE_Match object; span=(0, 12), match='/əɾ.t̪ʰɑːt̪/'>
# <Response [200]>
# <_sre.SRE_Match object; span=(0, 7), match='/əɾd̪ʱ/'>
# <Response [200]>
# <_sre.SRE_Match object; span=(0, 19), match='/əɾ.d̪ʱə.t̪ət̪.səm/'>
# <Response [200]>
# <_sre.SRE_Match object; span=(0, 9), match='/əɾ.pɪt̪/'>
# <Response [200]>
# <_sre.SRE_Match object; span=(0, 12), match='/ə.ləŋ.kɑːɾ/'>
# <Response [200]>
# <_sre.SRE_Match object; span=(0, 16), match='/ə.ləɡ.t̪ʰə.ləɡ/'>
# <Response [200]>
# <_sre.SRE_Match object; span=(0, 9), match='/əl.ɡɑːʋ/'>
# <Response [200]>
# <_sre.SRE_Match object; span=(0, 15), match='/əl.ɡɑːʋ.ʋɑːd̪/'>
# <Response [200]>
# <_sre.SRE_Match object; span=(0, 18), match='/əl.ɡɑːʋ.ʋɑː.d̪iː/'>
# <Response [200]>
# <_sre.SRE_Match object; span=(0, 7), match='/ə.ləm/'>
# <Response [200]>
# <_sre.SRE_Match object; span=(0, 12), match='/əl.mɑː.ɾiː/'>
# <Response [200]>
# <_sre.SRE_Match object; span=(0, 12), match='/əl.ʋɪ.d̪ɑː/'>
# <Response [200]>
# <_sre.SRE_Match object; span=(0, 12), match='/ə.lɑːp.nɑː/'>
# <Response [200]>
# None
# None
# <Response [200]>
# <_sre.SRE_Match object; span=(0, 8), match='/ə.lɑːʋ/'>
# <Response [200]>
# <_sre.SRE_Match object; span=(0, 12), match='/ə.liː.ɡəɽʱ/'>
# <Response [200]>
# <_sre.SRE_Match object; span=(0, 15), match='/əl.pə.kɑː.ɾiː/'>
# <Response [200]>
# <_sre.SRE_Match object; span=(0, 15), match='/əlp.səŋkʰ.jək/'>
# <Response [200]>
# <_sre.SRE_Match object; span=(0, 9), match='/əl.fɑːz/'>
# <Response [200]>
# <_sre.SRE_Match object; span=(0, 9), match='/əl.lɑːʱ/'>
# <Response [200]>
# <_sre.SRE_Match object; span=(0, 13), match='/əʋ.kə.ləd͡ʒ/'>
# <Response [200]>
# <_sre.SRE_Match object; span=(0, 11), match='/əʋ.kə.lən/'>
# <Response [200]>
# <_sre.SRE_Match object; span=(0, 15), match='/əʋ.kə.lə.niːj/'>
# <Response [200]>
# <Response [200]>
# <_sre.SRE_Match object; span=(0, 13), match='/əʋ.kʃeː.pən/'>
# <Response [200]>
# <_sre.SRE_Match object; span=(0, 8), match='/əʋ.ɡʊn/'>
# <Response [200]>
# <_sre.SRE_Match object; span=(0, 11), match='/ə.ʋəɡ.jɑː/'>
# <Response [200]>
# <_sre.SRE_Match object; span=(0, 9), match='/əʋ.t̪əl/'>
# <Response [200]>
# <_sre.SRE_Match object; span=(0, 10), match='/əʋ.t̪ɑːɾ/'>
# <Response [200]>
# <_sre.SRE_Match object; span=(0, 9), match='/ə.ʋəd̪ʱ/'>
# <Response [200]>
# <_sre.SRE_Match object; span=(0, 14), match='/əʋ.d̪ʱɑː.ɾən/'>
# <Response [200]>
# <_sre.SRE_Match object; span=(0, 15), match='/əʋ.d̪ʱɑːɾ.nɑː/'>
# <Response [200]>
# <_sre.SRE_Match object; span=(0, 10), match='/əʋ.d̪ʱiː/'>
# <_sre.SRE_Match object; span=(0, 12), match='/ə.ʋə.d̪ʱiː/'>
# <Response [200]>
# <_sre.SRE_Match object; span=(0, 9), match='/əʋ.pəŋk/'>
# <Response [200]>
# <_sre.SRE_Match object; span=(0, 8), match='/əʋ.jəʋ/'>
# <Response [200]>
# <_sre.SRE_Match object; span=(0, 12), match='/əʋ.loː.kən/'>
# <Response [200]>
# <_sre.SRE_Match object; span=(0, 12), match='/əʋ.ʃoː.ʃən/'>
# <Response [200]>
# <_sre.SRE_Match object; span=(0, 13), match='/əʋ.ʃoː.ʃɪt̪/'>
# <Response [200]>
# <_sre.SRE_Match object; span=(0, 8), match='/ə.ʋəʃj/'>
# <Response [200]>
# <Response [200]>
# <_sre.SRE_Match object; span=(0, 10), match='/əʋ.ɦəʈʈʰ/'>
# <Response [200]>
# <_sre.SRE_Match object; span=(0, 13), match='/əʋ.ɦeːl.nɑː/'>
# <Response [200]>
# <_sre.SRE_Match object; span=(0, 9), match='/ə.ʋɑːiː/'>
# <Response [200]>
# <_sre.SRE_Match object; span=(0, 8), match='/ə.ʋɑːm/'>
# <Response [200]>
# <_sre.SRE_Match object; span=(0, 9), match='/ə.ʋɑːɾɖ/'>
# <Response [200]>
# <_sre.SRE_Match object; span=(0, 14), match='/ə.ʋɪ.kɑː.ɾiː/'>
# <Response [200]>
# <_sre.SRE_Match object; span=(0, 12), match='/ə.ʋɪ.t͡ʃəl/'>
# <Response [200]>
# <_sre.SRE_Match object; span=(0, 10), match='/ə.ʋɪ.nəj/'>
# <Response [200]>
# <_sre.SRE_Match object; span=(0, 11), match='/ə.ʋɪ.ləmb/'>
# <Response [200]>
# <_sre.SRE_Match object; span=(0, 15), match='/ə.ʋɪ.ʋɑː.ɦɪt̪/'>
# <Response [200]>
# <_sre.SRE_Match object; span=(0, 10), match='/əʋ.jəkt̪/'>
# <Response [200]>
# <_sre.SRE_Match object; span=(0, 8), match='/əʋ.ʋəl/'>
# <Response [200]>
# <_sre.SRE_Match object; span=(0, 9), match='/ə.ʃəkt̪/'>
# <Response [200]>
# <_sre.SRE_Match object; span=(0, 11), match='/ə.ʃəɾ.fiː/'>
# <Response [200]>
# <_sre.SRE_Match object; span=(0, 8), match='/ə.ʃɪʃʈ/'>
# <Response [200]>
# <_sre.SRE_Match object; span=(0, 8), match='/ə.ʃʊbʱ/'>
# <Response [200]>
# <_sre.SRE_Match object; span=(0, 9), match='/əʃ.liːl/'>
# <Response [200]>
# None
# <Response [200]>
# <_sre.SRE_Match object; span=(0, 5), match='/əʃʋ/'>
# <Response [200]>
# <_sre.SRE_Match object; span=(0, 14), match='/əʃ.ʋə.meːd̪ʱ/'>
# <Response [200]>
# <_sre.SRE_Match object; span=(0, 11), match='/əʃ.ʋɪ.niː/'>
# <Response [200]>
# <_sre.SRE_Match object; span=(0, 10), match='/əʃʈ.koːn/'>
# <Response [200]>
# <_sre.SRE_Match object; span=(0, 12), match='/əʃʈ.bʱʊd͡ʒ/'>
# <Response [200]>
# <_sre.SRE_Match object; span=(0, 12), match='/ə.səŋ.ɡət̪/'>
# <Response [200]>
# <_sre.SRE_Match object; span=(0, 13), match='/ə.sən.t̪ʊʃʈ/'>
# <Response [200]>
# <_sre.SRE_Match object; span=(0, 12), match='/ə.səm.bʱəʋ/'>
