# %%
import re
import requests
import requests_html
import string
import pandas as pd

# %%
CATEGORY = 'Category:Hindi_terms_with_IPA_pronunciation'
LIMIT = 500    #number of vocab or 'TITLE'
INITIAL_QUERY = f'https://en.wiktionary.org/w/api.php?action=query&format=json&list=categorymembers&cmtitle={CATEGORY}&cmlimit={LIMIT}'
CONTINUE_TEMPLATE = string.Template(INITIAL_QUERY + "&cmcontinue=$cmcontinue")

PAGE_TEMPLATE = string.Template("https://en.wiktionary.org/wiki/$word")     # $_ -> placeholder for values of a dictionary. Template class of string library.

LI_SELECTOR = '//li[sup[a[@title = "Appendix:Hindi pronunciation"]] and span[@class = "IPA"]]' #language specific
SPAN_SELECTOR = '//span[@class = "IPA"]'       # what is this 'span' doing? 
PHONEMES = r"/(.+?)/"   #language specific

# %%
def _yield_phn(request):
    for li in request.html.xpath(LI_SELECTOR):
        for span in li.xpath(SPAN_SELECTOR):
            print(span.text, '\n\n')
            m = re.search(PHONEMES, span.text)
            if m:
                yield m

                
                
            #(<a href="/wiki/Appendix:Hindi_pronunciation" title="Appendix:Hindi pronunciation">key</a>)</sup>:&#32;<span class="IPA">/ə.səm.bʱɑː.ʋɪt̪/</span></li></ul>

# %%
def _print_data(data):
    session = requests_html.HTMLSession()
    """" <example of data>
query":{"categorymembers":[{"pageid":81811,"ns":0,"title":"Homo sapiens"},
{"pageid":3072481,"ns":0,"title":"\u0901"}...."""
    
    for member in data["query"]["categorymembers"]:
        word = member["title"]   
        # Skips multiword examples.
        if " " in word:
            continue
        query = PAGE_TEMPLATE.substitute(word=word)
        request = session.get(query)  #Grab a list of all links on the page
        for m in _yield_phn(request):
            pron = m.group(1)   #IPA without //. m.group(0) =  /IPA/ 
            #print(f"{word}\t{pron}")

# %%
def main():
    data = requests.get(INITIAL_QUERY).json()
    print('Data is requested, and now put to _print_data function.')
    _print_data(data)
    print('Initial query is processed.')
    code = data["continue"]["cmcontinue"]  
    next_query = CONTINUE_TEMPLATE.substitute(cmcontinue=code)
    i = 1
    while True:
        print('while loop is started.')
        data = requests.get(next_query).json()
        print(f'{i+1} request is done')
        _print_data(data)
        print(f'{i+1} request query is processed.')
        i += 1    
        # Then this is the last one.
        
        if not "continue" in data:
            break
        code = data["continue"]["cmcontinue"]   
        next_query = CONTINUE_TEMPLATE.substitute(cmcontinue=code)
        
if __name__ == "__main__":
    main()
# Out:
# Data is requested, and now put to _print_data function.
# [ə̃]
#
#
# [ə̃ŋ]
#
#
# [ə̃ɲ]
#
#
# [ə̃ɳ]
#
#
# [ə̃n]
#
#
# [ə̃m]
#
#
# /ə/
#
#
# /ə̃/
#
#
# /ə̃ɡ.ɾeː.ziː/
#
#
# /ə̃ʈ.nɑː/
#
#
# /ə̃/
#
#
# /əŋk/
#
#
# /əŋ.kən/
#
#
# /əŋ.kəl/
#
#
# /əŋ.kɪt̪/
#
#
# /əŋ.kʊɾ/
#
#
# /əŋ.kʊ.ɾɪt̪/
#
#
# /əŋ.kʊʃ/
#
#
# /əŋɡ/
#
#
# /əŋ.ɡət͡ʃ.t͡ʃʰeːd̪/
#
#
# /əŋɡ.ɽɑːiː/
#
#
# /əŋɡ.d̪ɑːn/
#
#
# /əŋ.ɡə.nɑː/
#
#
# /əŋ.ɡʱiːn/
#
#
# /əŋ.ɡɑːɾ/
#
#
# /əŋ.ɡɑː.ɾɑː/
#
#
# /əŋ.ɡiː.jɑː/
#
#
# /əŋ.ɡiː.ʈʰiː/
#
#
# /əŋ.ɡʊl/
#
#
# /əŋ.ɡʊ.liː/
#
#
# /əŋ.ɡuː.ʈʰɑː/
#
#
# /əŋ.ɡuːɾ/
#
#
# /əŋ.ɡoː.t͡ʃʰɑː/
#
#
# /əŋ.ɡoːʈ/
#
#
# /əŋɡ.ɾeːz/
#
#
# /əŋɡ.ɾeː.ziː.jət̪/
#
#
# /əŋɡ.ɾeː.ziː/
#
#
# /əŋɡ.ɾeː.d͡ʒiː/
#
#
# /əɲ.t͡ʃəl/
#
#
# /əɲ.t͡ʃʰəɾ/
#
#
# /əɲ.d͡ʒən/
#
#
# /əɲ.d͡ʒɑːm/
#
#
# /əɲ.d͡ʒiːɾ/
#
#
# /əɲ.d͡ʒuː/
#
#
# /ənʈ.sənʈ/
#
#
# /ən.ʈɑːɾ.kə.ʈɪ.kɑː/
#
#
# [ə̃ɳɖəkoʃ]
#
#
# /ən.ɖɑː/
#
#
# /ən.ɖoː.ɾɑː/
#
#
# /ənt̪/
#
#
# /ən.t̪əʰk.ʃeːp/
#
#
# /ənt̪.ɽiː/
#
#
# /ən.t̪ə.ɾəŋɡ.t̪ɑː/
#
#
# /ən.t̪əɾ.d͡ʒɑːl/
#
#
# /ən.t̪əɾ.ɾɑːʃʈ.ɾiː.jə.t̪ɑː/
#
#
# /ənt̪.ɾɑː/
#
#
# /ən.t̪ə.ɾɑː/
#
#
# /ən.t̪ə.ɾɑːl/
#
#
# /ənt̪.ɾɪkʃ/
#
#
# /ənt̪.ɾɪm/
#
#
# /ən.t̪əɾ.ɡət̪/
#
#
# /ən.t̪əɾ.d͡ʒɑː.t̪iːj/
#
#
# /ən.t̪əɾ.d͡ʒɑːl/
#
#
# /ən.t̪əɾ.d̪eː.ʃiːj/
#
#
# /ən.t̪əɾ.nɪ.ɦɪt̪/
#
#
# /ən.t̪əɾ.ɾɑːʃʈ.ɾiːj/
#
#
# /ən.t̪əɾ.ʋɑː.siː/
#
#
# /ən.t̪ɑːk.ʃə.ɾiː/
#
#
# /ən.t̪ɪm/
#
#
# /ənt̪.jeːʃ.ʈiː/
#
#
# /ən.d̪əɾ/
#
#
# /ən̪ˈd̪az/
#
#
# [ən̪ˈd̪äːz]
#
#
# [ən̪ˈd̪äːzäː]
#
#
# /ən.d̪ʱəɽ/
#
#
# /ənd̪ʱ.ʋɪʃ.ʋɑːs/
#
#
# /ən.d̪ʱɑː.d̪ʱʊnd̪ʱ/
#
#
# /ən.d̪ʱeː.ɾɑː/
#
#
# /əm.bəɾ/
#
#
# /ənʃ/
#
#
# /ənʃ.kɑː.lɪk/
#
#
# /ənʃ.t̪əʰ/
#
#
# /əʰ/
#
#
# /ə.kəɽ/
#
#
# /ə.kəɾm/
#
#
# /ə.kəɾ.mən.jə.t̪ɑː/
#
#
# /ə.kəs.mɑːt̪/
#
#
# /əkl/
#
#
# /əql/
#
#
# /ə.kəl/
#
#
# /ə.qəl/
#
#
# /ə.kəl.mənd̪/
#
#
# /ə.qəl.mənd̪/
#
#
# /əkl.mənd̪/
#
#
# /əql.mənd̪/
#
#
# /ə.kɑːd͡ʒ/
#
#
# /ə.kɑːd̪.mɪk/
#
#
# /ə.kɑːd̪.miː/
#
#
# /ə.kɑː.ɾən/
#
#
# /ə.kɑː.ɾət̪ʰ/
#
#
# /ə.kɑːl/
#
#
# /ə.kuːt̪/
#
#
# /ə.keː.lɑː/
#
#
# /ə.keː.lɑː.pən/
#
#
# /ək.kʰəɽ/
#
#
# /ək.kʰɑː/
#
#
# /ək.ʈuː.bəɾ/
#
#
# /ək.t̪uː.bəɾ/
#
#
# /ək.ʃət̪/
#
#
# /əkˈʃəj/
#
#
# /ˈəkʃɛ/
#
#
# /ək.ʃə.ɾɑː.ɾəmbʱ/
#
#
# /əks/
#
#
# /ək.səɾ/
#
#
# /ə.kʰəɳɖ/
#
#
# /ə.kʰənɖ.t̪ɑː/
#
#
# /ə.kʰəɾ.nɑː/
#
#
# /əkʰ.bɑːɾ/
#
#
# /əx.bɑːɾ/
#
#
# /əkʰ.bɑːɾ.ʋɑː.lɑː/
#
#
# /əx.bɑːɾ.ʋɑː.lɑː/
#
#
# /əkʰ.ɾoːʈ/
#
#
# /əx.ɾoːʈ/
#
#
# /ə.kʰɑː.ɽɑː/
#
#
# /ə.kʰɪl/
#
#
# /ə.ɡə.nɪt̪/
#
#
# /ə.ɡəɾ/
#
#
# /ə.ɡəɾ.t͡ʃeː/
#
#
# /ə.ɡəɾ.t̪ə.lɑː/
#
#
# /ə.ɡəɾ.bət̪.t̪iː/
#
#
# /əɡ.lɑː/
#
#
# /ə.ɡəst̪/
#
#
# /ə.ɡɪn/
#
#
# /ə.ɡʊɑː/
#
#
# /əɡ.niː/
#
#
# /əɡ.nɪ.pə.ɾiːk.ʃɑː/
#
#
# /əɡ.nɪ.ʃɑː.mək/
#
#
# /əɡn.jɑː.ʃəj/
#
#
# /əɡ.ɾəd͡ʒ/
#
#
# /əɡ.ɾɪm/
#
#
# /ə.t͡ʃəm.bʱɑː/
#
#
# /ət͡ʃ.kən/
#
#
# /ə.t͡ʃəɾ/
#
#
# /ət͡ʃ.ɾəd͡ʒ/
#
#
# /ə.t͡ʃɑː.nək/
#
#
# /ə.t͡ʃuːk/
#
#
# /ət͡ʃ.t͡ʃʰɑː/
#
#
# /ət͡ʃ.t͡ʃʰɑː.kʰɑː.sɑː/
#
#
# /ət͡ʃ.t͡ʃʰɑː.xɑː.sɑː/
#
#
# /ət͡ʃːɑpən/
#
#
# [ət͡ʃːäpən]
#
#
# /ət͡ʃʰ.nɑː/
#
#
# /ə.t͡ʃʰuːt̪/
#
#
# /ə.d͡ʒəb/
#
#
# /əd͡ʒ.meːɾ/
#
#
# /əd͡ʒ.moːd̪/
#
#
# /əd͡ʒ.ʋɑːɪn/
#
#
# /əz.d̪ə.ɦɑː/
#
#
# /ə.zəɾ.bɛː.d͡ʒɑːn/
#
#
# /ə.zɑːn/
#
#
# /ə.zɑːb/
#
#
# /ə.ziːz/
#
#
# /ə.ziːm/
#
#
# /ə.d͡ʒɑː.jəb.ɡʱəɾ/
#
#
# /ə.d͡ʒiː/
#
#
# /ə.d͡ʒiːb/
#
#
# /ə.d͡ʒiːɾn/
#
#
# /ə.d͡ʒuː.bɑː/
#
#
# /ə.d͡ʒeːn.ɖɑː/
#
#
# /əɡjaːt̪/
#
#
# /əɡ.jɑːn.pən/
#
#
# /ə.ʈək/
#
#
# /ə.ʈək.nɑː/
#
#
# /əʈ.kɑː.nɑː/
#
#
# /əʈ.kɑːʋ/
#
#
# /ə.ʈəl/
#
#
# /ə.ʈɛː.t͡ʃiː/
#
#
# /əʈ.ʈʰɑːiːs/
#
#
# /əʈ.ʈʰɑːn.ʋeː/
#
#
# /əʈ.ʈʰɑː.ʋən/
#
#
# /əʈ.ʈʰɑː.siː/
#
#
# /ə.ʈʰən.niː/
#
#
# /əʈʰ.pə.ɦiː.jɑː/
#
#
# /əʈʰ.pəiː.jɑː/
#
#
# /əʈʰ.ɦət̪.t̪əɾ/
#
#
# /əɽ.t̪ɑː.liːs/
#
#
# /əɽ.t̪iːs/
#
#
# /əɽ.səʈʰ/
#
#
# /ə.ɽɑː.nɑː/
#
#
# /ə.ɽiː.jəl/
#
#
# /ə.nuː/
#
#
# /ə.t̪əʰ/
#
#
# /ə.t̪iː/
#
#
# [ət̪ɪt̪ʰi]
#
#
# /ə.t̪ɪ.ʋɑːd̪/
#
#
# /ə.t̪ɪ.ʋɑː.d̪iː/
#
#
# /ə.t̪ɪʃ.joːk.t̪iː/
#
#
# /ə.t̪ɪ.səm.ʋeː.d̪ən.ʃiːl/
#
#
# /ə.t̪ɪ.sɑːɾ/
#
#
# /ə.t̪iːt̪/
#
#
# /ə.t̪ʊlj/
#
#
# /ət̪.fɑːl/
#
#
# /ət̪.jənt̪/
#
#
# /ət̪.jɑː.t͡ʃɑːɾ/
#
#
# /ə.t̪ʰɑːʱ/
#
#
# /ə.d̪əb/
#
#
# /əd̪.ɾək/
#
#
# /ə.d̪ɑː/
#
#
# /ə.d̪ɑː.kɑːɾ/
#
#
# /əd̪.jə.t̪ən/
#
#
# [ədʱərm]
#
#
# /ə.d̪ʱiː/
#
#
# /ə.d̪ʱɪk.t̪əm/
#
#
# /ə.d̪ʱɪk.t̪ɑː/
#
#
# /ə.d̪ʱɪ.kɑːɾ/
#
#
# [ədʱɪkari]
#
#
# /ə.d̪ʱɪ.nɑː.jək/
#
#
# /ə.d̪ʱɪ.niː.jəm/
#
#
# /ə.d̪ʱɪ.bʱɑːɾ/
#
#
# /ə.d̪ʱɪ.mɑːs/
#
#
# /ə.d̪ʱɪ.lɑːbʱ/
#
#
# /ə.d̪ʱɪ.ʋək.t̪ɑː/
#
#
# /ə.d̪ʱɪ.ʋɑːɾ.ʃɪ.kiː/
#
#
# /ə.d̪ʱɪ.suːt͡ʃ.nɑː/
#
#
# /ə.d̪ʱiːk.ʃək/
#
#
# /ə.d̪ʱiːk.ʃən/
#
#
# /ə.d̪ʱiːn/
#
#
# /ə.d̪ʱiːɾ/
#
#
# /ə.d̪ʱiːʃ/
#
#
# /ə.d̪ʱuː.ɾɑː/
#
#
# /ə.d̪ʱeːɽ/
#
#
# /ə.d̪ʱoː.ɦəs.t̪ɑːk.ʃə.ɾiː/
#
#
# /əd̪ʱ.jəkʃ.t̪ɑː/
#
#
# /əd̪ʱ.jə.jən/
#
#
# /əd̪ʱ.jən/
#
#
# /əd̪ʱ.jɑː.d̪eːʃ/
#
#
# /əd̪ʱ.jɑː.pək/
#
#
# /ən/
#
#
# /ən.kə.ɦɑː/
#
#
# /ən.ɡɪ.nət̪/
#
#
# /ən.t͡ʃɑː.ɦɑː/
#
#
# /ən.d͡ʒɑː.nɑː/
#
#
# [ənd̪ekʰa]
#
#
# /ən.pət͡ʃ/
#
#
# /ən.pəɽʱ/
#
#
# /ən.mə.nɑː/
#
#
# /ən.ʃən/
#
#
# /ə.nəs.t̪ɪt̪ʋ/
#
#
# /ən.ɦoː.niː/
#
#
# /ə.nɑːd͡ʒ/
#
#
# /ə.nɑː.ɽiː/
#
#
# /ə.nɑː.t̪oː.liː/
#
#
# /ə.nɑː.t̪ʰɑː.ləj/
#
#
# /ə.nɑː.d̪ʱɪ.kɑː.ɾɪk/
#
#
# [ənaːm]
#
#
# /ə.nɑː.mɪ.kɑː/
#
#
# /ən̪aːr/
#
#
# /ə.nɑːɾ.d̪ɑː.nɑː/
#
#
# /ə.niː.jə.mɪt̪/
#
#
# /ə.nɪ.ʋɑːɾj/
#
#
# /ə.nɪ.ʋɑːɾ.jə.t̪əʰ/
#
#
# /ə.nɪʃ.t͡ʃɪt̪/
#
#
# /ə.nuː/
#
#
# [ənʊkərəɳ]
#
#
# /ə.nʊ.kuːl/
#
#
# /ə.nʊ.kuː.lən/
#
#
# [ənʊtʃʰːeːd]
#
#
# /ə.nʊɡ.jəp.t̪iː/
#
#
# /ə.nʊ.nɑːd̪/
#
#
# /ə.nʊˈnɑː.sɪk/
#
#
# [ənʊpəm]
#
#
# /ə.nuː.pəs.t̪ʰɪt̪/
#
#
# /ə.nʊ.pɑːt̪/
#
#
# /ə.nʊ.puː.ɾək/
#
#
# /ə.nʊ.pɾə.jʊkt̪/
#
#
# /ə.nʊp.ɾɑːs/
#
#
# /ə.nʊ.bʱə.ʋiː/
#
#
# /ə.nʊ.bʱuː.t̪iː/
#
#
# /ə.nʊ.mɑːn.t̪əʰ/
#
#
# /ə.nʊ.mɑː.nɪt̪/
#
#
# /ən̪ʊmod̪ən̪/
#
#
# /ə.nʊ.jɑː.jiː/
#
#
# /ə.nʊ.ɾək.ʃən/
#
#
# /ə.nʊ.ɾoːd̪ʱ/
#
#
# /ə.nʊ.ʋɑːn.ʃɪk/
#
#
# /ə.nʊ.ʋɑːn.ʃɪ.kiː/
#
#
# /ə.nʊ.ʋɑːd̪/
#
#
# /ə.nʊ.ʋɑː.d̪ɪt̪/
#
#
# /ə.nʊ.ʃɑː.sən/
#
#
# /ə.nʊ.ʃɑː.sɪt̪/
#
#
# /ə.nʊ.ʃiː.lən/
#
#
# /ə.nʊʃ.ʈʰɑːn/
#
#
# /ə.nʊ.sən.d̪ʱɑːn/
#
#
# /ə.nʊ.sə.ɾən/
#
#
# /ə.nʊs.ʋɑːɾ/
#
#
# /ə.nuː.ʈʰɑː/
#
#
# /ə.nuː.d̪ɪt̪/
#
#
# /ə.neːk/
#
#
# /ə.nɔːp.t͡ʃɑː.ɾɪk/
#
#
# /ən.d̪əɾ/
#
#
# /ənn/
#
#
# /ənj/
#
#
# /ən.jə.t̪ʰɑː/
#
#
# /ən.jɑːj/
#
#
# /əp.t̪əʈ/
#
#
# /ə.pət̪j/
#
#
# /əp.d̪eːʃ/
#
#
# /əp.nɑː/
#
#
# /əp.neː.ɑːp/
#
#
# /əp.mɑːn/
#
#
# /əp.mɑː.nɪt̪/
#
#
# [əpradʱ]
#
#
# /əp.ɾɑː.d̪ʱiː/
#
#
# /ə.pə.ɾɪ.t͡ʃɪt̪/
#
#
# /əp.ɾɪ.pəkʋ/
#
#
# /ə.pə.ɾɪ.meːj/
#
#
# /ə.pə.ɾɪ.ɾʊd̪d̪ʱ/
#
#
# /əp.ʋɑːd̪/
#
#
# /ə.pə.ʋɪt̪ɾ/
#
#
# /əp.ʃə.kʊn/
#
#
# /əp.sɑː.mɑːnj/
#
#
# /ə.pʰə.ɾən/
#
#
# /ə.pʰəɾ.t̪ɑː/
#
#
# /ə.pɪ.t̪uː/
#
#
# /ə.pʊʃʈ/
#
#
# /ə.puːɾn/
#
#
# /ə.puːɾʋ/
#
#
# /ə.peːk.ʃɑː/
#
#
# /ə.peːk.ʃɪt̪/
#
#
# /ə.pɔːɪnʈ.meːnʈ/
#
#
# /əp.ɾət̪.jɑː.ʃɪt̪/
#
#
# /əp.ɾɛːl/
#
#
# /əp.sə.ɾɑː/
#
#
# /əf.ʋɑːʱ/
#
#
# /əf.səɾ/
#
#
# /əf.sɑː.nɑː/
#
#
# /əf.soːs.d͡ʒə.nək/
#
#
# /ə.fiːm/
#
#
# /əf.sɑː.nɑː/
#
#
# [əˈpʰim]
#
#
# /əb.ʈɑː.bɑːd̪/
#
#
# /ə.bɑː.biːl/
#
#
# /ə.bɪ.t͡ʃəl/
#
#
# /ə.bɪ.ʋɑːt̪t̪/
#
#
# /ə.biːɾ/
#
#
# /əb.bɑː/
#
#
# /əbɾ/
#
#
# /əb.ɾuː/
#
#
# /ə.bʱɑːʋ/
#
#
# /ə.bʱɪ.kə.lɪt̪ɾ/
#
#
# /ə.bʱɪ.kɑː.ɾək/
#
#
# /ə.bʱɪk.ɾiː.jɑː/
#
#
# /ə.bʱɪ.ɡəm/
#
#
# /ə.bʱɪd̪.ɾɪʃ.jək/
#
#
# /ə.bʱɪ.nəj/
#
#
# /ə.bʱɪ.neː.t̪ɑː/
#
#
# /ə.bʱɪ.neːt̪.ɾiː/
#
#
# /ə.bʱɪp.ɾɑːj/
#
#
# /ə.bʱɪ.bʱɑː.ʋək/
#
#
# /ə.bʱiː.jən.t̪ɑː/
#
#
# /ə.bʱiː.jənt̪.ɾɪ.kiː/
#
#
# /ə.bʱiː.jɑːnt̪.ɾɪ.kiː/
#
#
# /ə.bʱiː.jɑːn/
#
#
# /əbʱijʊkt̪/
#
#
# /ə.bʱiː.joːk.t̪ɑː/
#
#
# /ə.bʱiː.joːɡ/
#
#
# /ə.bʱiː.joː.d͡ʒək/
#
#
# /ə.bʱɪ.ɾʊ.t͡ʃiː/
#
#
# /ə.bʱɪ.lɑː.ʃɑː/
#
#
# /ə.bʱɪʋ.jək.t̪iː/
#
#
# /əbʱiː/
#
#
# /ə.bʱuːt̪.puːɾʋ/
#
#
# /əbʱ.jəst̪/
#
#
# /əbʱ.jɑːs/
#
#
# /əbʱ.jɑːs.kɾəm/
#
#
# /əbʱ.jɑːs.ʋəʃ/
#
#
# /əbʱ.ɾək/
#
#
# /ə.mən/
#
#
# /əm.ɾiː.kɑː/
#
#
# /əm.ɾuːd̪/
#
#
# /ə.məl/
#
#
# /ə.miːɾ/
#
#
# /ə.meː.ɾɪ.kɑː/
#
#
# /ə.meː.ɾɪ.kiː/
#
#
# /əm.bəɾ/
#
#
# /əm.mɑː/
#
#
# /əm.mɑ̃ː/
#
#
# /əm.miː/
#
#
# /əml/
#
#
# /əml.t̪ɑː/
#
#
# /əm.lə.t̪ɑː/
#
#
# /əml.pɪt̪t̪/
#
#
# /əm.lə.pɪt̪t̪/
#
#
# /əm.liːj/
#
#
# /ə.jəs/
#
#
# /ə.jəsk/
#
#
# /ə.joːd̪ʱ.jɑː/
#
#
# /ə.ɾəkt̪.t̪ɑː/
#
#
# /ə.ɾəɡ.niː/
#
#
# /ə.ɾəb/
#
#
# /əɾ.bɪnd̪/
#
#
# /əɾ.mɑːn/
#
#
# /əɾ.ʋɪnd̪/
#
#
# /ə.ɾɪ.ɦənt̪/
#
#
# /ə.ɾʊ.t͡ʃiː/
#
#
# /ə.ɾʊ.noː.d̪əj/
#
#
# /ə.ɾeː/
#
#
# /əɾz/
#
#
# /əɾ.ziː/
#
#
# /əɾ.d͡ʒʊn/
#
#
# /əɾ.d͡ʒeːn.ʈiː.nɑː/
#
#
# /ˈəɾt̪ʰ/
#
#
# /əɾ.t̪ʰə.puːɾn/
#
#
# /əɾ.t̪ʰə.mɪ.t̪iː/
#
#
# /əɾ.t̪ʰəʋ.jə.ʋəs.t̪ʰɑː/
#
#
# /əɾ.t̪ʰə.ʃɑːst̪.ɾiː/
#
#
# /əɾ.t̪ʰɑːt̪/
#
#
# /əɾd̪ʱ/
#
#
# /əɾ.d̪ʱə.t̪ət̪.səm/
#
#
# /əɾ.pɪt̪/
#
#
# /ə.ləŋ.kɑːɾ/
#
#
# /ə.ləɡ.t̪ʰə.ləɡ/
#
#
# /əl.ɡɑːʋ/
#
#
# /əl.ɡɑːʋ.ʋɑːd̪/
#
#
# /əl.ɡɑːʋ.ʋɑː.d̪iː/
#
#
# /ə.ləm/
#
#
# /əl.mɑː.ɾiː/
#
#
# /əl.ʋɪ.d̪ɑː/
#
#
# /ə.lɑːp.nɑː/
#
#
# [əˈl̪ɑːɾm]
#
#
# [əˈl̪ɑː.ɾəm]
#
#
# /ə.lɑːʋ/
#
#
# /ə.liː.ɡəɽʱ/
#
#
# /əl.pə.kɑː.ɾiː/
#
#
# /əlp.səŋkʰ.jək/
#
#
# /əl.fɑːz/
#
#
# /əl.lɑːʱ/
#
#
# /əʋ.kə.ləd͡ʒ/
#
#
# /əʋ.kə.lən/
#
#
# /əʋ.kə.lə.niːj/
#
#
# /əʋ.kʃeː.pən/
#
#
# /əʋ.ɡʊn/
#
#
# /ə.ʋəɡ.jɑː/
#
#
# /əʋ.t̪əl/
#
#
# /əʋ.t̪ɑːɾ/
#
#
# /ə.ʋəd̪ʱ/
#
#
# /əʋ.d̪ʱɑː.ɾən/
#
#
# /əʋ.d̪ʱɑːɾ.nɑː/
#
#
# /əʋ.d̪ʱiː/
#
#
# /ə.ʋə.d̪ʱiː/
#
#
# /əʋ.pəŋk/
#
#
# /əʋ.jəʋ/
#
#
# /əʋ.loː.kən/
#
#
# /əʋ.ʃoː.ʃən/
#
#
# /əʋ.ʃoː.ʃɪt̪/
#
#
# /ə.ʋəʃj/
#
#
# /əʋ.ɦəʈʈʰ/
#
#
# /əʋ.ɦeːl.nɑː/
#
#
# /ə.ʋɑːiː/
#
#
# /ə.ʋɑːm/
#
#
# /ə.ʋɑːɾɖ/
#
#
# /ə.ʋɪ.kɑː.ɾiː/
#
#
# /ə.ʋɪ.t͡ʃəl/
#
#
# /ə.ʋɪ.nəj/
#
#
# /ə.ʋɪ.ləmb/
#
#
# /ə.ʋɪ.ʋɑː.ɦɪt̪/
#
#
# /əʋ.jəkt̪/
#
#
# /əʋ.ʋəl/
#
#
# /ə.ʃəkt̪/
#
#
# /ə.ʃəɾ.fiː/
#
#
# /ə.ʃɪʃʈ/
#
#
# /ə.ʃʊbʱ/
#
#
# /əʃ.liːl/
#
#
# [əʃliːlt̪aː]
#
#
# /əʃʋ/
#
#
# /əʃ.ʋə.meːd̪ʱ/
#
#
# /əʃ.ʋɪ.niː/
#
#
# /əʃʈ.koːn/
#
#
# /əʃʈ.bʱʊd͡ʒ/
#
#
# /ə.səŋ.ɡət̪/
#
#
# /ə.sən.t̪ʊʃʈ/
#
#
# /ə.səm.bʱəʋ/
#
#
# Initial query is processed.
# while loop is started.
# 2 request is done
# /ə.səm.bʱɑː.ʋɪt̪/
#
#
# /ə.səm.ʋeː.d̪ən.ʃiːl/
#
#
# /ə.səm.ʋɛː.d̪ʱɑː.nɪk/
#
#
# /ə.sət̪j/
#
#
# /ə.sət̪.jɑː.bʱɑːs/
#
#
# /ə.sə.pʰəl/
#
#
# /ə.səm/
#
#
# /ə.səɾ/
#
#
# /əs.liː.jət̪/
#
#
# /əs.liː/
#
#
# /ə.sɛːʱ.mə.t̪iː/
#
#
# /ə.səʱ.joːɡ/
#
#
# /əs.ɦɑːj/
#
#
# /ə.sə.ɦɪʃ.nuː/
#
#
# /ə.sə.ɦɪʃ.nʊ.t̪ɑː/
#
#
# /ə.sɑː.d̪ʱɑː.ɾən/
#
#
# [ɑ.sɑm.ɑːdʒ.ɪk]
#
#
# /ə.sʊn.d̪əɾ/
#
#
# /ə.sʊ.ɾək.ʃɪt̪/
#
#
# /ə.sʊ.ʋɪ.d̪ʱɑː/
#
#
# /ə.sɛː.nɪk/
#
#
# /əs.t̪ə.bəl/
#
#
# /əs.t̪ɪt̪ʋ/
#
#
# /əst̪ɾ.ʃəst̪ɾ/
#
#
# /əs.t̪ʰə.mɑː/
#
#
# /əs.t̪ʰɑː.jiː/
#
#
# /əs.t̪ʰiː/
# /əs.t̪ʰɪ.pəɲ.d͡ʒəɾ/
#
#
# /əs.pə.t̪ɑːl/
#
#
# /əˈspɾɪʃ.jə/
#
#
# /əs.mɪ.t̪ɑː/
#
#
# /əs.siː/
#
#
# /ɛːʱm/
#
#
# /eː.ɦeːŋ.kɑːɾ/
#
#
# /ɛːʱ.bɑːb/
#
#
# /ɛːʱm/
#
#
# /ɛːʱ.miː.jət̪/
#
#
# /ə.ɦɑː.t̪ɑː/
#
#
# /ə.ɦɪt͡ʃ.t͡ʃʰət̪ɾ/
#
#
# /ə.ɦɪ.nɑːʱ/
#
#
# /ə.ɦɪbʱ.ɾɪt̪/
#
#
# /ə.ɦɪɾ.bʊʃn/
#
#
# /ə.ɦɪ.ʋɑːt̪/
#
#
# /ə.ɦɪ.ʋɑːd̪/
#
#
# /ɑː/
#
#
# /aː/
#
#
# /a/
#
#
# /ɑː/
#
#
# [äː]
#
#
# /ɑ̃ːkʰ/
#
#
# /ɑ̃ː.ɡən/
#
#
# /ɑ̃ːt͡ʃ/
#
#
# /ɑ̃ː.suː/
#
#
# /ɑːŋk.ɽɑː/
#
#
# /ɑːŋ.ɡən/
#
#
# /ɑːnt̪.ɾɪk/
#
#
# /ɑːn.d̪oː.lən/
#
#
# /ɑ̃ːʋ.lɑː/
#
#
# /ɑːn.ʃɪk/
#
#
# /ɑːɪn.d̪ɑː/
#
#
# /ɑːɪ.zoːl/
#
#
# /ɑːɪs.kɾiːm/
#
#
# /ɑːɪsɖ/
#
#
# /ɑːiː/
#
#
# /ɑːiː.lɑː/
#
#
# /ɑːuː/
#
#
# /ɑːk/
#
#
# /ɑː.kəɾ.ʃək/
#
#
# /ɑː.kəɾ.ʃən/
#
#
# /ɑː.kəɾ.ʃɪt̪/
#
#
# /ɑː.kə.lən/
#
#
# /ɑː.kəs.mɪk/
#
#
# /ɑː.kɑːŋk.ʃɑː/
#
#
# /ɑː.kɑːŋk.ʃiː/
#
#
# /ɑː.kɑːɾ/
#
#
# [aːkaːʃ]
#
#
# /ɑː.kɑːʃ.ʋɑː.niː/
#
#
# /ɑːk.ɾɪ.t̪iː/
#
#
# /ɑːk.ɾə.mən/
#
#
# /ɑːk.ɾə.mən.kɑː.ɾiː/
#
#
# /ɑːk.ɾɑː.mək/
#
#
# /ɑːk.ɾɑː.mək.t̪ɑː/
#
#
# /ɑːk.ɾoːʃ/
#
#
# /ɑː.kʰɪɾ/
#
#
# /ɑː.xɪɾ/
#
#
# /ɑː.kʰɪɾ.kɑːɾ/
#
#
# /ɑː.xɪɾ.kɑːɾ/
#
#
# /ɑːkʰ.ɾiː/
#
#
# /ɑːx.ɾiː/
#
#
# /ɑː.kʰɪ.ɾiː/
#
#
# /ɑː.xɪ.ɾiː/
#
#
# /ɑːɡ/
#
#
# /aːɡ.zə.niː/
#
#
# /ɑː.ɡɑːz/
#
#
# /ɑː.ɣɑːz/
#
#
# /ɑː.ɡoːʃ/
#
#
# /ɑː.ɣoːʃ/
#
#
# /ɑː.ɡɑːʱ/
#
#
# /ɑː.ɡɑː.ɦiː/
#
#
# /ɑːɡ.neːj/
#
#
# /ɑːɡ.neː.jɑːst̪ɾ/
#
#
# /ɑːɡ.ɾəʱ/
#
#
# /ɑːɡʱ/
#
#
# /ɑː.ɡʱɑːt̪/
#
#
# /ɑː.t͡ʃə.ɾən/
#
#
# /ɑː.t͡ʃʰɑː/
#
#
# /ɑːd͡ʒ/
#
#
# /ɑːz.mɑː.nɑː/
#
#
# /ɑː.zɑːd̪/
#
#
# /ɑːɡ.jɑː/
#
#
# [ˈɑːʈɑ]
#
#
# /ɑː.ɖəm.bəɾ/
#
#
# /ɑːɖ.ʋɑː.niː/
#
#
# /ɑːɽ/
#
#
# /ɑː.ɽuː/
#
#
# /ɑːn.ʋɪk/
#
#
# /ɑː.t̪əŋk.məj/
#
#
# /ɑː.t̪əŋ.kɪt̪/
#
#
# /ɑːt̪.miː.jə.t̪ɑː/
#
#
# /ɑː.t̪ɪʃ.bɑː.ziː/
#
#
# /ɑː.t̪ɪʃ.bɑː.d͡ʒiː/
#
#
# /ɑː.t̪ʊɾ/
#
#
# /ɑːt̪m/
#
#
# /ɑːt̪.mək/
#
#
# /ɑːt̪.mə.kə.t̪ʰɑː/
#
#
# /ɑːt̪.mə.ɡʱɑːt̪/
#
#
# /ɑːt̪.mə.ɡʱɑː.t̪iː/
#
#
# /ɑːt̪.mə.ʋɪʃ.ʋɑːs/
#
#
# /ɑːt̪m.sə.məɾ.pən/
#
#
# /ɑːt̪.mə.sɑːt̪/
#
#
# /ɑːt̪.mə.sɑːt̪/
#
#
# /ɑːt̪.məs.t̪ʊ.t̪iː/
#
#
# /ɑːt̪m.ɦət̪.jɑː/
#
#
# /ɑːt̪.miːj/
#
#
# /ɑː.d̪ə.t̪ən/
#
#
# /ɑː.d̪əm/
#
#
# /ɑːd̪.miː/
#
#
# /ɑː.d̪əɾ/
#
#
# /ɑː.d̪əɾ.puːɾ.ʋək/
#
#
# /ɑː.d̪əɾʃ/
#
#
# /ɑː.d̪ɑːn/
#
#
# /ɑː.d̪ɑːn.pɾə.d̪ɑːn/
#
#
# /ɑː.d̪ɑːb/
#
#
# [ˈɑːd̪i]
#
#
# /ɑː.d̪ɪ.bʱɑː.ʃɑː/
#
#
# /ɑː.d̪ɪm/
#
#
# /ɑː.d̪ɪ.ʋɑː.siː/
#
#
# /ɑː.d̪iː/
#
#
# /ɑː.d̪eːʃ/
#
#
# /ɑː.d̪ʱɑːɾ/
#
#
# /ɑː.d̪ʱɑːɾ.bʱuːt̪/
#
#
# /ɑː.d̪ʱɪk/
#
#
# /ɑː.d̪ʱɪ.pət̪j/
#
#
# /ɑː.d̪ʱʊ.nɪ.kiː.kə.ɾən/
#
#
# /ɑːd̪ʱ.jɑːt̪.mɪk/
#
#
# /ɑː.nənd̪.d̪ɑː.jiː/
#
#
# [ɑːn̪ɑː]
#
#
# /ɑːn.d̪oː.lən/
#
#
# /aːp/
#
#
# [aːpkaː]
#
#
# /ɑː.pət̪.t̪iː/
#
#
# /ɑː.pət̪.t̪iː.d͡ʒə.nək/
#
#
# /ɑːp.d̪ɑː/
#
#
# /ɑːp.biː.t̪iː/
#
#
# /ɑː.pəs/
#
#
# /ɑː.pɑːt̪.kɑːl/
#
#
# /ɑː.puːɾ.t̪iː/
#
#
# /ɑː.peːk.ʃɪk/
#
#
# /ɑː.fət̪/
#
#
# /ɑːf.t̪ɑːb/
#
#
# /aːfriːd̪iː/
#
#
# /ɑːb/
#
#
# /ɑːb.eː.t͡ʃəʃm/
#
#
# /ɑːb.d̪əst̪/
#
#
# /ɑːb.ɾuː/
#
#
# /ɑːb.lɑː/
#
#
# /ɑːm/
#
#
# /ɑː.mənt̪.ɾɪt̪/
#
#
# /ɑː.məd̪.niː/
#
#
# /ɑːm.ʋɑːt̪/
#
#
# /ɑː.mɑː.ʃəj/
#
#
# /ɑː.mʊkʰ/
#
#
# /ɑː.jət̪/
#
#
# /ɑː.jə.t̪ən/
#
#
# /ɑː.jən/
#
#
# /ɑː.jɑː/
#
#
# /ɑː.jɑːt̪/
#
#
# /ɑː.juː/
#
#
# /ɑː.jʊkt̪/
#
#
# /ɑː.jʊɾ.ʋɪɡ.jɑːn/
#
#
# /ɑː.jʊɾ.ʋeːd̪/
#
#
# /ɑː.joːɡ/
#
#
# /ɑː.joː.d͡ʒən/
#
#
# /ɑː.joː.d͡ʒɪt̪/
#
#
# /ɑː.ɾəm.bʱɪk/
#
#
# /ɑː.ɾək.ʃən/
#
#
# /ɑːɾ.zuː/
#
#
# /ɑː.ɾɑːm/
#
#
# [ɑːˈɾɑːm]
#
#
# /ɑː.ɾɑːm.kʊɾ.siː/
#
#
# /ɑː.ɾɑːm.d̪eːʱ/
#
#
# [aːroːˈɡjə]
#
#
# /ɑː.ɾoːp/
#
#
# /ɑːɾ.t̪ʰɪ.kiː/
#
#
# /ɑːɾ.meː.niː.jən/
#
#
# /ɑːɾ.jə.mən/
#
#
# /ɑː.ləs/
#
#
# /ɑːl.siː/
#
#
# /ɑː.ləsj/
#
#
# /ɑː.liː.ʃɑːn/
#
#
# /ɑː.leːkʰ/
#
#
# /ɑː.loːt͡ʃ.nɑː/
#
#
# /ɑː.ʋən.ʈən/
#
#
# /ɑː.ʋən.ʈɪt̪/
#
#
# /ɑː.ʋək/
#
#
# /ɑː.ʋəɾ.d̪ʱən/
#
#
# /ɑː.ʋɑː/
#
#
# /ə.ʋɑːz/
#
#
# /ɑː.ʋɑːz/
#
#
# /ɑː.ʋɑː.ɦən/
#
#
# /ɑː.ʋɪʃ.kɑːɾ/
#
#
# /ɑːʋ.ɾɪt̪.t̪iː/
#
#
# /ɑː.ʋeː.d̪ən/
#
#
# /ɑː.ʋeː.d̪ən.kəɾ.t̪ɑː/
#
#
# /ɑː.ʋeːʃ/
#
#
# /ɑː.ʋeː.ʃɪt̪/
#
#
# /ɑːʋ.juːʱ/
#
#
# /ɑː.ʃəŋ.kɑː/
#
#
# /ɑːʃ.nɑː/
#
#
# /ɑː.ʃəj/
#
#
# /ɑː.ʃɑː.ʋɑːd̪/
#
#
# /ɑː.ʃɪk.mɪ.zɑːd͡ʒ/
#
#
# /ɑː.ʃɪq.mɪ.zɑːd͡ʒ/
#
#
# /ɑː.ʃɪ.kiː/
#
#
# /ɑː.ʃɪ.qiː/
#
#
# /ɑː.ʃiː.jɑː.nɑː/
#
#
# /ɑː.ʃɪʃ/
#
#
# /ɑː.ʃiːɾ.ʋɑːd̪/
#
#
# /ɑː.ʃʊ.lɪ.piː/
#
#
# /ɑːʃ.t͡ʃəɾj/
#
#
# /ɑːʃ.ɾəm/
#
#
# /ɑːʃ.ɾəj/
#
#
# /ɑːʃ.ʋɑː.sən/
#
#
# /ɑːs/
#
#
# /ɑːs.pɑːs/
#
#
# /ɑː.sən/
#
#
# /ɑː.sənn/
#
#
# /ɑːs.mɑː.niː/
#
#
# /ɑːs.ɾɑː/
#
#
# /ɑː.sə.ʋən/
#
#
# /ɑː.sɑː.miː/
#
#
# /ɑː.sɑːɾ/
#
#
# /ɑːs.t̪iːn/
#
#
# /ɑːs.t̪ʰɑː/
#
#
# /ɑːʱ/
#
#
# /ɑː.ɦəʈ/
#
#
# /ɑː.ɦət̪/
#
#
# /ɑː.ɦɑːɾ/
#
#
# /ɑːɪs.t̪ɑː/
#
#
# /ɑː.ɦɪs.t̪ɑː/
#
#
# /ɪ/
#
#
# /i/
#
#
# /ɪn.kə.lɑːb/
#
#
# /ɪn.qə.lɑːb/
#
#
# /ɪŋɡ.lɪs.t̪ɑːn/
#
#
# /ɪŋɡ.lɛːnɖ/
#
#
# /ɪɲt͡ʃ/
#
#
# /ɪɲ.t͡ʃiː.joːn/
#
#
# /ɪɲ.d͡ʒən/
#
#
# /ɪɲ.d͡ʒiː.niː.jəɾ/
#
#
# /ɪɲ.d͡ʒiː.niː.jə.ɾiː/
#
#
# /ɪɲ.d͡ʒiːl/
#
#
# /ɪn.ʈəɾ.feːs/
#
#
# /ɪn.ʈəɾʋ.juː/
#
#
# /ɪn.ʈeːl/
#
#
# /ɪn.ɖəsʈ.ɾiː/
#
#
# /ɪn.ɖoː.neː.ʃiː.jən/
#
#
# /ɪn.ɖoː.neː.ʃiː.jɑː/
#
#
# /ɪn.t̪ə.kɑːm/
#
#
# /ɪn.t̪ə.qɑːm/
#
#
# /ɪn.t̪ə.kɑːl/
#
#
# /ɪn.t̪ə.qɑːl/
#
#
# /ɪn.t̪ə.kʰɑːb/
#
#
# /ɪn.t̪ə.xɑːb/
#
#
# /ɪn.t̪ə.zɑːɾ/
#
#
# /ɪn.t̪ə.ɦɑː/
#
#
# /ɪn.t̪ɪ.fɑː.d̪ɑː/
#
#
# /ɪn.t̪ɪ.ɦɑː/
#
#
# /ɪn.d̪ʊɾ/
#
#
# /ɪn.d̪ɔːɾ/
#
#
# /ɪnd̪.ɾə.nɑːt̪ʰ/
#
#
# /ɪnd̪.ɾɪj/
#
#
# /ɪm.pʰɑːl/
#
#
# /ɪns.peːk.ʈəɾ/
#
#
# /ɪk/
#
#
# /ɪ.kəʈ.ʈʰɑː/
#
#
# /ɪk.t̪ɑː.liːs/
#
#
# /ɪ.kət̪.t̪iːs/
#
#
# /ɪk.nɑː.liː/
#
#
# /ɪ.kə.pʰiː.jɑː/
#
#
# /ɪk.lɔː.t̪ɑː/
#
#
# /ɪk.səʈʰ/
#
#
# /ɪk.sɪŋ.ɡɑː/
#
#
# /ɪ.kʰət̪.t̪əɾ/
#
#
# /ɪ.kət̪.t̪əɾ/
#
#
# /ɪk.kiːs/
#
#
# /ɪk.jɑːn.ʋeː/
#
#
# /ɪk.jɑː.ʋən/
#
#
# /ɪk.jɑː.siː/
#
#
# /ɪkʰ.t̪iː.jɑːɾ/
#
#
# /ɪx.t̪iː.jɑːɾ/
#
#
# /ɪɡ.luː/
#
#
# /ɪt͡ʃ.t͡ʃʰɑː/
#
#
# /ɪz.ɦɑːɾ/
#
#
# /ɪ.zɑː.fɑː/
#
#
# /ɪz.zət̪/
#
#
# /ɪ.d͡ʒɑː.zət̪/
#
#
# /ɪʈ.liː/
#
#
# /ɪ.ʈə.liː/
#
#
# /ɪɖ.liː/
#
#
# /ɪ.t̪əɾ/
#
#
# /ɪt̪.ɾɑː.nɑː/
#
#
# /ɪˈt̪aːl.viː/
#
#
# /ɪ.t̪ɪ.ɦɑːs/
#
#
# /ɪ.t̪ɪ.ɦɑːs.kɑːɾ/
#
#
# /ɪt̪.t̪eː.lɑː/
#
#
# /ɪt̪.miː.nɑːn/
#
#
# /ɪt̪.jɑː.d̪iː/
#
#
# /ɪt̪ɾ/
#
#
# /ɪ.t̪ʰiː.joː.piː.jɑː/
#
#
# [ɪn̪kaː]
#
#
# /ɪn.kɑːɾ/
#
#
# /ɪn.koː/
#
#
# /ɪn.sɑːf/
#
#
# /ɪn.ɦẽ/
#
#
# /ɪ.bɑː.d̪ət̪/
#
#
# /ɪb.t̪ɪ.d̪ɑː/
#
#
# /ɪb.t̪ɪ.d̪ɑːiː/
#
#
# /ɪb.ɾɑː.ɦiːm/
#
#
# /ɪm.d̪ɑːd̪/
#
#
# /ɪm.lɑː/
#
#
# /ɪm.liː/
#
#
# /ɪ.mɑː.ɾət̪/
#
#
# /ɪ.mɑː.ɾə.t̪iː/
#
#
# /ɪ.moː.d͡ʒiː/
#
#
# /ɪ.moː.ʃən/
#
#
# /ɪm.t̪ə.ɦɑːn/
#
#
# /ɪm.t̪ɪ.ɦɑːn/
#
#
# /ɪm.t̪eː.ɦɑːn/
#
#
# /iː.jət̪/
#
#
# /iː.jɑː/
#
#
# /ɪ.ɾɑːd̪.t̪ən/
#
#
# /ɪ.ɾɑː.d̪ɑː/
#
#
# /ɪɾd̪.ɡɪɾd̪/
#
#
# /ɪl.zɑːm/
#
#
# /ɪ.lɑːd͡ʒ/
#
#
# /ɪ.lɑː.jə.t͡ʃiː/
#
#
# /ɪ.lɑː.ɦɑː.bɑːd̪/
#
#
# /ɪ.lɑː.ɦiː/
#
#
# /ɪl.t̪ɪ.d͡ʒɑː/
#
#
# /ɪʃk/
#
#
# /ɪʃk/
#
#
# /ɪʃq/
#
#
# /ɪʃ.t̪ə.ɦɑːɾ/
#
#
# /ɪʃ.t̪ɪ.ɦɑːɾ/
#
#
# [ɪskaː]
#
#
# /ɪs.koː/
#
#
# /ɪs.mɑːiːl/
#
#
# /ɪs.mẽ/
#
#
# /ɪs.ɾɑːɾ/
#
#
# /ɪs.ɾoː/
#
#
# /ɪs.lɪeː/
#
#
# /ɪs.seː/
#
#
# /ɪ.siː.lɪeː/
#
#
# /ɪ.seː/
#
#
# /ɪs.t̪ək.bɑːl/
#
#
# /ɪs.t̪əq.bɑːl/
#
#
# /ɪs.t̪ɑːn.bʊl/
#
#
# /ɪs.t̪iː.fɑː/
#
#
# /ɪs.t̪eː.mɑːl/
#
#
# /ɪs.pɑːt̪/
#
#
# /ɪsm/
#
#
# /ɪs.meː.ʃə.ɾiːf/
#
#
# /ɪ.səm.eː.ʃə.ɾiːf/
#
#
# /ɪs.ɾɑːɪl/
#
#
# [ɪslaːm]
#
#
# /ɪs.lɑː.mɑː.bɑːd̪/
#
#
# /iː/
#
#
# /iː/
#
#
# /i/
#
#
# [iː]
#
#
# /iːnʈ/
#
#
# /iːn.d̪ʱən/
#
#
# /iː.kə.ɾən/
#
#
# /iːk.ɾən/
#
#
# /iː.d͡ʒiː.jən/
#
#
# /iː.ʈɑːn.ɡəɾ/
#
#
# /iːd̪/
#
#
# [iːmaːn̪]
#
#
# /iː.mɑːn.d̪ɑːɾ/
#
#
# /iː.meːl/
#
#
# /iː.ɾɑːk/
#
#
# /iː.ɾɑːn/
#
#
# /iː.ɾɑː.niː/
#
#
# /iːɾʃ.jɑː/
#
#
# /iː.lɑː/
#
#
# /iːʃ/
#
#
# /iːʃ.ʋəɾ/
#
#
# /iː.sɑː/
#
#
# [iːˈsɑ̟ːiː]
#
#
# /ʊ/
#
#
# /ʊ̃.ɖeːl.nɑː/
#
#
# /ʊŋɡ.liː/
#
#
# /ʊɲ.t͡ʃɑːiː/
#
#
# [ʊns]
#
#
# /ʊk.sɑː.nɑː/
#
#
# /ʊ.kɑːb/
#
#
# /ʊ.qɑːb/
#
#
# /ʊkt̪/
#
#
# /ʊɡ.nɑː/
#
#
# /ʊ.ɡəl.nɑː/
#
#
# /ʊɡɾ/
#
#
# /ʊ.t͡ʃək.nɑː/
#
#
# /ʊ.t͡ʃək.kɑː/
#
#
# /ʊ.t͡ʃɪt̪/
#
#
# /ʊt͡ʃ.t͡ʃɑː.jʊkt̪/
#
#
# /ʊt͡ʃ.t͡ʃɑː.joːɡ/
#
#
# /ʊt͡ʃ.t͡ʃɑː.ɾən/
#
#
# /ʊt͡ʃ.t͡ʃʰeː.d̪ən/
#
#
# /ʊ.d͡ʒəɽ.nɑː/
#
#
# /ʊ.d͡ʒəɖɖ/
#
#
# /ʊd͡ʒ.lɑː/
#
#
# /ʊz.beːk/
#
#
# /ʊ.d͡ʒɑː.ɡəɾ/
#
#
# /ʊ.d͡ʒɑː.lɑː/
#
#
# /ʊʈʰ.nɑː/
#
#
# /ʊ.ɽəd̪/
#
#
# /ʊɽ.nɑː/
#
#
# /ʊ.ɽɑːn/
#
#
# /ʊɽʱ.kɑː.nɑː/
#
#
# /ʊ.t̪əɾ.nɑː/
#
#
# /ʊ.t̪əɾ.ʋɑː.nɑː/
#
#
# /ʊ.t̪ɑːɾ.nɑː/
#
#
# /ʊt̪k.ɾɪʃʈ/
#
#
# /ʊt̪.t̪əm/
#
#
# /ʊt̪.t̪əɾ.kɑː.ʃiː/
#
#
# /ʊt̪.t̪əɾ.d̪ɑː.jɪt̪ʋ/
#
#
# /ʊt̪.t̪əɾ.d̪ɑː.jiː/
#
#
# /ʊt̪.t̪ə.ɾɑː.kʰənɖ/
#
#
# /ʊt̪.t̪ə.ɾɑː.d̪ʱɪ.kɑː.ɾiː/
#
#
# /ʊt̪.t̪ə.ɾɑːɾd̪d̪ʱ/
#
#
# /ʊt̪ːedʒɪt̪/
#
#
# /ʊt̪.t̪oː.lək/
#
#
# /ʊt̪.t̪oː.lən/
#
#
# /ʊt̪.pət̪.t̪iː/
#
#
# /ʊt̪.pənn/
#
#
# /ʊt̪.pənn/
#
#
# /ʊt̪.pəl/
#
#
# /ʊt̪.pɑːd̪/
#
#
# /ʊt̪.pɑː.d̪ən/
#
#
# /ʊt̪.piː.ɽən/
#
#
# /ʊt̪p.ɾeː.ɾək/
#
#
# /ʊt̪.səɾ.d͡ʒən/
#
#
# /ʊt̪.sɑːʱ/
#
#
# /ʊt̪.sɑː.ɦɪt̪/
#
#
# /ʊt̪.sʊk/
#
#
# /ʊt̪.sʊk.t̪ɑː/
#
#
# /ʊd̪.ɡəd̪.ɾiː/
#
#
# /ʊ.d̪əj.ʋəɾʃ/
#
#
# /ʊ.d̪ɑːɾ.t̪ɑː/
#
#
# /ʊ.d̪ɑːɾ.t̪ɑː.ʋɑːd̪/
#
#
# /ʊ.d̪ɑːɾ.ʋɑːd̪/
#
#
# /ʊ.d̪ɑːs/
#
#
# /ʊ.d̪ɑː.siːn/
#
#
# /ʊ.d̪ɑːʱ.ɾən/
#
#
# /ʊ.d̪ʱɑː.ɾən/
#
#
# /ʊd̪.ɡʱɑː.ʈən/
#
#
# /ʊd̪.d̪eː.ʃɪ.kɑː/
#
#
# /ʊd̪.bʱəʋ/
#
#
# /ʊd̪.jə.miː/
#
#
# /ʊd̪.jɑːn/
#
#
# /ʊd̪.joːɡ/
#
#
# /ʊd̪.joːɡ.pə.t̪iː/
#
#
# /ʊd̪.joː.ɡiː/
#
#
# /ʊd̪.joː.ɡiː.kə.ɾən/
#
#
# /ʊ.d̪ʱəɽ.nɑː/
#
#
# /ʊ.d̪ʱɑːɾ/
#
#
# /ʊ.d̪ʱeːɽ.nɑː/
#
#
# [ʊn̪kaː]
#
#
# /ʊn.koː/
#
#
# /ʊn.t͡ʃɑːs/
#
#
# /ʊn.t̪ɑː.liːs/
#
#
# /ʊn.t̪iːs/
#
#
# /ʊn.səʈʰ/
#
#
# /ʊn.ɦət̪.t̪əɾ/
#
#
# /ʊ.niːn.d̪ɑː/
#
#
# /ʊn.nət̪/
#
#
# /ʊn.nɑːʋ/
#
#
# /ʊn̪maːd̪/
#
#
# /ʊn.mʊkt̪/
#
#
# /ʊn.muː.lən/
#
#
# /ʊn.jɑː.siː/
#
#
# /ʊn.ɦẽ/
#
#
# /ʊn.ɦoːn.neː/
#
#
# /ʊn.ɦõː.neː/
#
#
# /ʊp.kə.ɾən/
#
#
# /ʊp.kɑːɾ/
#
#
# /ʊp.t͡ʃɑːɾ/
#
#
# 2 request query is processed.
# while loop is started.
# 3 request is done
# /ʊp.t͡ʃʊ.nɑːʋ/
#
#
# /ʊ.pəd͡ʒ.nɑː/
#
#
# /ʊp.d͡ʒɑːuː/
#
#
# /ʊp.nə.ɡəɾ/
#
#
# /ʊp.nɑː.jɪ.kɑː/
#
#
# /ʊ.pən.jɑːs/
#
#
# /ʊ.pən.jɑːs.kɑːɾ/
#
#
# /ʊp.pət̪.t̪iː/
#
#
# /ʊp.boː.liː/
#
#
# /ʊp.bʱoːk.t̪ɑː/
#
#
# /ʊp.bʱoːɡ/
#
#
# /ʊp.bʱoːd͡ʒj/
#
#
# /ʊp.joːɡ/
#
#
# [ʊpjoɡɪt̪aː]
#
#
# /ʊp.joː.ɡiː/
#
#
# /ʊp.ləbd̪ʱ/
#
#
# /ʊp.lɑː/
#
#
# /ʊp.ʋɑːs/
#
#
# /ʊ.pəs.t͡ʃɪʋ/
#
#
# /ʊp.səɾɡ/
#
#
# /ʊ.pəs.t̪ʰɪ.t̪iː/
#
#
# /ʊ.pʰɑːɾ/
#
#
# /ʊ.pɑː.d̪ʱiː/
#
#
# /ʊ.pɑːd̪ʱ.jɑːj/
#
#
# /ʊ.pɑːj/
#
#
# /ʊ.pɑː.sək/
#
#
# /ʊ.peːk.ʃɑː/
#
#
# /ʊf/
#
#
# /ʊ.bəɾ.nɑː/
#
#
# /ʊ.bɑːuː/
#
#
# /ʊ.bɑːl.nɑː/
#
#
# /ʊ.bʱəɾ.nɑː/
#
#
# /ʊ.məɽ.nɑː/
#
#
# /ʊ.məɾ/
#
#
# /ʊ.məs/
#
#
# /ʊm.d̪ɑː/
#
#
# /ʊm.miːd̪.ʋɑːɾ/
#
#
# /ʊm.miːd̪.ʋɑːɾ/
#
#
# /ʊm.ɾə.kɛːd̪/
#
#
# /ʊm.ɾə.qɛːd̪/
#
#
# /ʊ.ɾʊm.t͡ʃiː/
#
#
# /ʊ.ɾoːs.t̪ʰiː/
#
#
# /ʊɾ.d̪uː/
# /ʊɾf/
#
#
# /ʊɾ.ʋə.ɾək/
#
#
# /ʊl.d͡ʒʱən/
#
#
# /ʊ.ləd͡ʒʱ.nɑː/
#
#
# /ʊl.d͡ʒʱɑː.nɑː/
#
#
# /ʊ.ləʈ.nɑː/
#
#
# /ʊl.ʈɑː/
#
#
# /ʊl.ʈiː/
#
#
# [ʊlfət̪]
#
#
# /ˈʊl.ɦnɑː/
#
#
# /ʊ.liːt͡ʃ.nɑː/
#
#
# /ʊ.luːk/
#
#
# /ʊl.kɑː/
#
#
# /ʊl.ʈɑː/
#
#
# /ʊl.ʈiː/
#
#
# /ʊl.ləŋ.ɡʱən/
#
#
# /ʊl.leːkʰ/
#
#
# /ʊl.leːkʰ.niːj/
#
#
# [ʊskaː]
#
#
# /ʊs.koː/
#
#
# /ʊs.mɑːn/
#
#
# /ʊs.seː/
#
#
# /ʊ.suːl/
#
#
# /ʊ.seː/
#
#
# /ʊs.t̪ɑːd̪/
#
#
# /uː/
#
#
# /ũː.t͡ʃɑː/
#
#
# /uː.t͡ʃɑː/
#
#
# /ũːʈ/
#
#
# /ũˈt͡ʃa/
#
#
# /uːkʰ/
#
#
# /uːd̪.bɪ.lɑːʋ/
#
#
# /uːn/
#
#
# /uː.nɑː/
#
#
# /uː.niː/
#
#
# /uː.pəɾ.ʋɑː.lɑː/
#
#
# /uːp.ɾiː/
#
#
# /uː.fɑː/
#
#
# /uːb/
#
#
# /uː.bəɽ.kʰɑː.bəɽ/
#
#
# /uːb.nɑː/
#
#
# /uːɾ.d͡ʒɑː/
#
#
# /uːʃ.miːk.ɾən/
#
#
# /uː.səɾ/
#
#
# /ɾiː/
#
#
# [ˈɾɪɡʋed̪]
#
#
# /ɾɪn/
#
#
# /ɾɪn.d̪ɑː.t̪ɑː/
#
#
# /ɾɪn.d̪ɑː.t̪ɑːoː/
#
#
# /ɾɪn.d̪ɑː.t̪ɑːoːn/
#
#
# /ɾɪ.nɑːɡɾ/
#
#
# /ɾɪ.nɑː.jən/
#
#
# /ɾɪ.ʃiː/
#
#
# /eː/
#
#
# /eː/
#
#
# /eːnɖ.ɾɔːɪɖ/
#
#
# /eːk.eːk/
#
#
# /eːk.ɡʱɑː.t̪iːj/
#
#
# /eːk.d͡ʒʊʈ/
#
#
# /eːk.d͡ʒʊʈ.t̪ɑː/
#
#
# /eː.kəɽ/
#
#
# /eː.kəɾ/
#
#
# /eːk.t̪əɾ.fɑː/
#
#
# /eː.kət̪ɾ/
#
#
# /eːk.ɾuːp.t̪ɑː/
#
#
# /eːk.ʋə.t͡ʃən/
#
#
# /eːk.ʋəɾ.niːj/
#
#
# /eː.kɑːnt̪/
#
#
# /eː.kɑːeːk/
#
#
# /eː.kɑːd̪ʱ/
#
#
# /eː.kɑː.d̪ʱɪ.kɑːɾ/
#
#
# /eː.kɛː.kiː.ɑːt͡ʃ.t͡ʃʰɑː.d̪ək/
#
#
# /eː.d͡ʒeːnʈ/
#
#
# /eː.d͡ʒeːn.siː/
#
#
# /eː.ʈiːeːm/
#
#
# /eː.ɽiː/
#
#
# /eː.ɖɪ.leːɖ/
#
#
# /eːt̪.bɑːɾ/
#
#
# /eːt̪.ɾɑːz/
#
#
# /eːm‿eːl‿eː/
#
#
# /eː.lɑːn/
#
#
# /eː.ʋəz/
#
#
# /eːʱ.t̪ə.d͡ʒɑːd͡ʒ/
#
#
# /eːʱ.sɑːn/
#
#
# /eːʱ.sɑːn.mənd̪/
#
#
# /ɛː/
#
#
# /ɛːt͡ʃ.t͡ʃʰɪk/
#
#
# /ɛːt̪.ɾɑːz/
#
#
# [ɛt̪ɪɦaːsɪk]
#
#
# /ɛː.nək/
#
#
# /ɛː.nɪ.meː/
#
#
# /əiː.jɑː.ʃiː/
#
#
# /ɛːʃ/
#
#
# /ɛːʃ.ʋəɾj/
#
#
# /ɛː.sɑː/
#
#
# /ɛː.siː/
#
#
# /ɛː.seː/
#
#
# /ɔːk.lɛːnɖ/
#
#
# /ɔːks.foːɾɖ/
#
#
# /oː/
#
#
# [oeː]
#
#
# /oːk/
#
#
# /okaːiː/
#
#
# /oːkʰ.liː/
#
#
# /oɡaːzm/
#
#
# /oː.t͡ʃʰɑː/
#
#
# /oː.d͡ʒʱɑː/
#
#
# /oː.ʈɑː.ʋɑː/
#
#
# /oː.ɖɪ.ʃɑː/
#
#
# /oːɽʱ.nɑː/
#
#
# /oː.nəm/
#
#
# /oːt̪.pɾoːt̪/
#
#
# /oː.ləm.pɪk/
#
#
# /oː.lɑː/
#
#
# /oː.lɪm.piː.jɑːɖ/
#
#
# /oːʃʈʰj/
#
#
# /oː.sɑː.kɑː/
#
#
# /oː.ɦɑː.joː/
#
#
# /ɔː/
#
#
# /aʊ/
#
#
# /əʊ/
#
#
# /ɔː.kɑːt̪/
#
#
# /ɔː.qɑːt̪/
#
#
# /ɔː.zɑːɾ/
#
#
# /ɔːd̪.joː.ɡɪk/
#
#
# /ɔːd̪.joː.ɡiː.kə.ɾən/
#
#
# /ɔːp.t͡ʃɑː.ɾɪk/
#
#
# [ɔːɾ]
#
#
# [ˈɔːɾət̪]
#
#
# /ɔː.lɑːd̪/
#
#
# /ɔː.ʃəd̪ʱ/
#
#
# /ɔːʃ.d̪ʱiːj/
#
#
# [ˈɔː.sət̪]
#
#
# /ɔːs.t̪ən/
#
#
# /k/
#
#
# /kə/
#
#
# /kəŋ.kəɽ/
#
#
# /kəŋk.ɽiː.lɑː/
#
#
# /kəŋ.kɑːl/
#
#
# /kəŋ.ɡən/
#
#
# [kə̃ɲ.d͡ʒuːs]
#
#
# [kə̃ɳʈʰ]
#
#
# /kənʈʰ.mɑː.lɑː/
#
#
# /kənʈʰj/
#
#
# /kən.ɖək.ʈəɾ/
#
#
# /kən.ɖiːʃ.nəɾ/
#
#
# /kəm.pən/
#
#
# /kəmp.juː.ʈəɾ/
#
#
# /kəmp.juːʈ.ɾiː.kə.ɾən/
#
#
# /kəm.bəl/
#
#
# /kəiː/
#
#
# /kək.ɽiː/
#
#
# /kəkʃ/
#
#
# /ˈkək.ʃɑː/
#
#
# /kə.ɡɑːɾ/
#
#
# /kət͡ʃ.nɑːɾ/
#
#
# /kət͡ʃ.ɾɑː/
#
#
# /kə.t͡ʃɛːʱ.ɾiː/
#
#
# /kət͡ʃ.t͡ʃɑː/
#
#
# /kət͡ʃt͡ʃʰ/
#
#
# /kə.t͡ʃʰɑː.ɾiː/
#
#
# /kəd͡ʒ.ɾɑː.ɾɑː/
#
#
# /kəʈ.nɑː/
#
#
# /kə.ʈʰəl/
#
#
# /kə.ʈɑːiː/
#
#
# /kə.ʈɑːɾ/
#
#
# /kə.ʈoː.ɾɑː/
#
#
# /kə.ʈɔː.t̪iː/
#
#
# /kəʈʰ.ɡʱə.ɾɑː/
#
#
# /kəʈʰ.mʊl.lɑː/
#
#
# /kəˈʈʰɪn/
#
#
# [kəʈʰɪnt̪ɑː]
#
#
# /kə.ʈʰʊɑː/
#
#
# /kəɽ.ʋɑː/
#
#
# /kəɽ.ʋɑː.pən/
#
#
# /kəɽ.ʋɑː.ɦəʈ/
#
#
# /kə.ɽɑː/
#
#
# /kə.ɽʱɑːiː/
#
#
# /kə.ɽʱiː/
#
#
# /kə.t̪ʰən/
#
#
# /kə.t̪ʰɑː/
#
#
# /kə.t̪ʰɪt̪/
#
#
# /kət̪ʰj/
#
#
# /kə.d̪ən/
#
#
# /kə.d̪ɑː.t͡ʃɪt̪/
#
#
# /kə.d̪ɑː.piː/
#
#
# /kəduː/
#
#
# /kədːuː/
#
#
# /kən.ʈoːp/
#
#
# /kən.pə.ʈiː/
#
#
# /kən.peːɽ/
#
#
# /kə.nɑː.ɖɑː/
#
#
# /kə.nɪʃʈʰ/
#
#
# /kə.niːz/
#
#
# /kən.nəɽ/
#
#
# /kən.nəɽ/
#
#
# /kən.nɔːd͡ʒ/
#
#
# /kən.ɦəiː.jɑː/
#
#
# /kəp.ɽɑː/
#
#
# [kəpal]
#
#
# /kə.pɑːs/
#
#
# /kə.pɪl.ʋəs.t̪uː/
#
#
# /kə.puːɾ/
#
#
# /kə.poːl.kəl.pɪt̪/
#
#
# /kəp.t̪ɑːn/
#
#
# [kəb]
#
#
# /kə.bəɖ.ɖiː/
#
#
# /kə.bɑːɽ/
#
#
# /kə.bɑːb/
#
#
# /kə.biːɾ/
#
#
# /kə.bʱiː/
#
#
# /kəm/
#
#
# /kəm/
#
#
# /kəm.zoːɾ/
#
#
# /kəm.bəkʰt̪/
#
#
# /kəm.bəxt̪/
#
#
# /kəm.ɾɑː/
#
#
# /kə.məl/
#
#
# /kəm.liː/
#
#
# /kə.mɑːiː/
#
#
# /kə.mɑːn/
#
#
# /kə.mɑːl/
#
#
# /kə.mɪʃ.nəɾ/
#
#
# [kəmi]
#
#
# /kə.miː.nɑː/
#
#
# /kə.miː.nɑː.pən/
#
#
# /kə.meːnʈ/
#
#
# /kə.meː.ʈiː/
#
#
# /kə.moː.beːʃ/
#
#
# /kəɾ/
#
#
# [kərke]
#
#
# /kəɾ.ɡʱɑː/
#
#
# [kərəɳ]
#
#
# /kəɾ.niː/
#
#
# /kəɾ.t̪əb/
#
#
# [kərta]
#
#
# [kərti]
#
#
# [kərte]
#
#
# /kəɾ.nɑː/
#
#
# /kəɾ.nɑːl/
#
#
# [kərneʋaːlaː]
#
#
# /kə.ɾɑː.t͡ʃiː/
#
#
# /kə.ɾɑː.ɾɑː/
#
#
# /kə.ɾɪʃ.mɑː/
#
#
# /kəɾũːŋɡɑ/
#
#
# /kə.ɾoːɽ/
#
#
# /kə.ɾoːɽ.pə.t̪iː/
#
#
# /kə.ɾɔːn.d̪ɑː/
#
#
# /kəɾn/
#
#
# /kəɾ.t̪əʋ.jə.pət̪ʰ/
#
#
# /kəɾ.t̪ɑː/
#
#
# /kəɾt̪.ɾɪt̪ʋ/
#
#
# /kəɾ.nɑː.ʈək/
#
#
# /kəɾm/
#
#
# /kəɾm.bʱuː.miː/
#
#
# /kəɾ.miː/
#
#
# /kə.ləŋk/
#
#
# /kə.lən/
#
#
# /kə.ləm.kɑː.ɾiː/
#
#
# /kəl.sɑː/
#
#
# /kə.ləʱ/
#
#
# [kəlɑː]
#
#
# /kə.lɑːiː/
#
#
# /kə.lɑːt̪.mək/
#
#
# /kə.lɑː.ʋənt̪/
#
#
# /kə.liː.siː.jɑː/
#
#
# /kəl.ʈiː/
#
#
# /kəl.pə.nɑː/
#
#
# /kəl.pə.nɑː.d̪əɾʃ/
#
#
# /kəl.pɪt̪/
#
#
# /kə.ʋək/
#
#
# /kə.ʋət͡ʃ/
#
#
# /kəʋ.jɪt̪.ɾiː/
#
#
# /ˈkə.vi/
#
#
# /ˈkə.vɪ/
#
#
# /kə.ʋɪ.t̪ɑː/
#
#
# /kə.ʋɪt̪t̪/
#
#
# /kə.ʃəm.kəʃ/
#
#
# /kəʃ.t̪iː/
#
#
# /kəʃ.miːɾ/
#
#
# /kəʃʈ.sɑːd̪ʱj/
#
#
# /kəs.keː/
#
#
# /kə.səɾ/
#
#
# /kəs.ɾət̪/
#
#
# /kə.sɔː.ʈiː/
#
#
# /kɛːʱ.nɑː/
#
#
# /kɛːʱ.lɑː.nɑː/
#
#
# /kəʱ.ʋɑː/
#
#
# /kə.ɦɑː/
#
#
# /kə.ɦɑː.niː/
#
#
# /kə.ɦɑː.niː.kɑːɾ/
#
#
# /kə.ɦɑː.ʋət̪/
#
#
# /kə.ɦĩː/
#
#
# /kə/
#
#
# /qə/
#
#
# /kət̪.ɾɑː/
#
#
# /qət̪.ɾɑː/
#
#
# /kət̪l/
#
#
# /qət̪l/
#
#
# /kət̪.leːɑːm/
#
#
# /qət̪.leːɑːm/
#
#
# /kəd̪/
#
#
# /qəd̪/
#
#
# /kə.d̪əm/
#
#
# /qə.d̪əm/
#
#
# /kə.d̪əm.t̪ɑːl/
#
#
# /qə.d̪əm.t̪ɑːl/
#
#
# /kə.d̪iːm/
#
#
# /qə.d̪iːm/
#
#
# /kəd̪.d̪ɑː.ʋəɾ/
#
#
# /qəd̪.d̪ɑː.ʋəɾ/
#
#
# /qəˈd̪əɾ/
#
#
# /kəˈd̪əɾ/
#
#
# /kəd̪.ɾə.d̪ɑːn/
#
#
# /qəd̪.ɾə.d̪ɑːn/
#
#
# /kə.biː.lɑː/
#
#
# /qə.biː.lɑː/
#
#
# /kə.buːl/
#
#
# /qə.buːl/
#
#
# /kəbz/
#
#
# /qəbz/
#
#
# /kəb.ɾɪs.t̪ɑːn/
#
#
# /qəb.ɾɪs.t̪ɑːn/
#
#
# /kə.miːz/
#
#
# /qə.miːz/
#
#
# /kə.ɾɑːɾ/
#
#
# /qə.ɾɑːɾ/
#
#
# /kə.ɾiːb/
#
#
# /qə.ɾiːb/
#
#
# /kə.ɾiː.bən/
#
#
# /qə.ɾiː.bən/
#
#
# /kəɾz/
#
#
# /qəɾz/
#
#
# /kə.ləm/
#
#
# /qə.ləm/
#
#
# /kəʋ.ʋɑːl/
#
#
# /qəʋ.ʋɑːl/
#
#
# /kəʋ.ʋɑː.liː/
#
#
# /qəʋ.ʋɑː.liː/
#
#
# /kə.səm/
#
#
# /qə.səm/
#
#
# /kə.siː.d̪ɑː/
#
#
# /qə.siː.d̪ɑː/
#
#
# /kə.suːɾ/
#
#
# /qə.suːɾ/
#
#
# /kəs.bɑː/
#
#
# /qəs.bɑː/
#
#
# /kɛːʱɾ/
#
#
# /qɛːʱɾ/
#
#
# /kəʱ.ʋɑː/
#
#
# /qəʱ.ʋɑː/
#
#
# /kɑː.ziː/
#
#
# /qɑː.ziː/
#
#
# /kɑː.t̪ɪl/
#
#
# /qɑː.t̪ɪl/
#
#
# /kɑː.t̪ɪ.lɑː.nɑː/
#
#
# /qɑː.t̪ɪ.lɑː.nɑː/
#
#
# [qaːnuːn]
#
#
# /kɑː.fɪ.lɑː/
#
#
# /qɑː.fɪ.lɑː/
#
#
# /kɑː.bɪl/
#
#
# /qɑː.bɪl/
#
#
# /kɑː.bɪ.liː.jət̪/
#
#
# /qɑː.bɪ.liː.jət̪/
#
#
# /kɑːj.d̪ɑː/
#
#
# /qɑːj.d̪ɑː/
#
#
# /kɑː.jəm/
#
#
# /qɑː.jəm/
#
#
# /kɑː.liːn/
#
#
# /qɑː.liːn/
#
#
# /kɑː.sɪd̪/
#
#
# /qɑː.sɪd̪/
#
#
# /kɪl.lət̪/
#
#
# /qɪl.lət̪/
#
#
# /kɪst̪/
#
#
# /qɪst̪/
#
#
# /kɪs.sɑː/
#
#
# /qɪs.sɑː/
#
#
# [qʊraːn̪]
#
#
# /kʊl.fiː/
#
#
# /qʊl.fiː/
#
#
# /kʊʋ.ʋət̪/
#
#
# /qʊʋ.ʋət̪/
#
#
# /kɛː/
#
#
# /qɛː/
#
#
# /kɛːɲ.t͡ʃiː/
#
#
# /qɛːɲ.t͡ʃiː/
#
#
# /qɛd̪e t̪ənɦai/
#
#
# /kɛːd̪.kʰɑː.nɑː/
#
#
# /qɛːd̪.xɑː.nɑː/
#
#
# /kɛː.d̪iː/
#
#
# /qɛː.d̪iː/
#
#
# /kɔːm/
#
#
# /qɔːm/
#
#
# /kɑː/
#
#
# /kɑ̃ːkʰ/
#
#
# /kɑ̃ːt͡ʃ/
#
#
# /kɑ̃ː.ʈɑː/
#
#
# /kɑ̃ːʋ/
#
#
# /kɑ̃ːs/
#
#
# /kɑːŋɡ.ɾeːs/
#
#
# /kɑːŋɡ.ɾeː.siː/
#
#
# /kɑːn.ʈɑː/
#
#
# /kɑːn.d̪ɑː/
#
#
# /kɑːn.sɑː/
#
#
# /kɑːn.siː/
#
#
# /ˈkɑː.kɑː/
#
#
# /kɑː.kiː/
#
#
# /kɑː.ɡəz/
#
#
# /kɑː.ɣəz/
#
#
# [ˈkɑːɡəz]
#
#
# [ˈkɑːɣəz]
#
#
# /kɑːɡ.zɑːt̪/
#
#
# /kɑːɣ.zɑːt̪/
#
#
# /kɑːd͡ʒ/
#
#
# /kɑː.d͡ʒəl/
#
#
# /ˈka.d͡ʒu/
#
#
# /kɑːʈ.nɑː/
#
#
# /kɑːʈʰ/
#
#
# /kɑːʈʰ.mɑːn.ɖuː/
#
#
# /kɑːɽʱ.nɑː/
#
#
# /kɑːn/
#
#
# /kɑːn.pʊɾ/
#
#
# /kɑː.nɑː/
#
#
# /kɑːn.ɦɑː/
#
#
# /kɑː.pʰiː/
#
#
# /kɑː.bʊ.kiː/
#
#
# /kɑːm/
#
#
# /kɑːm.kɑːd͡ʒ/
#
#
# /kɑːm.ɡɑːɾ/
#
#
# /kɑːm.nɑː/
#
#
# /kɑːm.jɑːb/
#
#
# /kɑːm.ʋɑː.liː/
#
#
# [kaːmiː]
#
#
# [kamʊk]
#
#
# [kamʊkt̪a]
#
#
# /kaːmon̪maːd̪/
#
#
# /kɑːj.koː/
#
#
# /kɑːj.nɑːt̪/
#
#
# /kɑː.jəɾ/
#
#
# /kɑːɾ/
#
#
# /kɑː.ɾək/
#
#
# /kɑː.ɾək/
#
#
# /kɑːɾ.kʰɑː.nɑː/
#
#
# /kɑːɾ.xɑː.nɑː/
#
#
# /kɑːɾ.ɡəɾ/
#
#
# [käːrəɳ]
#
#
# /kɑːɾ.t̪uːs/
#
#
# /kɑːɾ.nɑː.mɑː/
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-19-f3a61327c18e> in <module>()
#      22
#      23 if __name__ == "__main__":
# ---> 24     main()
#
# <ipython-input-19-f3a61327c18e> in main()
#      11         data = requests.get(next_query).json()
#      12         print(f'{i+1} request is done')
# ---> 13         _print_data(data)
#      14         print(f'{i+1} request query is processed.')
#      15         i += 1
#
# <ipython-input-18-2953c22edb4e> in _print_data(data)
#      12         query = PAGE_TEMPLATE.substitute(word=word)
#      13         request = session.get(query)  #Grab a list of all links on the page
# ---> 14         for m in _yield_phn(request):
#      15             pron = m.group(1)   #IPA without //. m.group(0) =  /IPA/
#      16             #print(f"{word}\t{pron}")
#
# <ipython-input-16-f7cd7d59ab0f> in _yield_phn(request)
#       1 def _yield_phn(request):
# ----> 2     for li in request.html.xpath(LI_SELECTOR):
#       3         for span in li.xpath(SPAN_SELECTOR):
#       4             print(span.text, '\n\n')
#       5             m = re.search(PHONEMES, span.text)
#
# ~/anaconda3/lib/python3.6/site-packages/requests_html.py in xpath(self, selector, clean, first, _encoding)
#     253         :class:`Element <Element>` found.
#     254         """
# --> 255         selected = self.lxml.xpath(selector)
#     256
#     257         elements = [
#
# ~/anaconda3/lib/python3.6/site-packages/requests_html.py in lxml(self)
#     158         if self._lxml is None:
#     159             try:
# --> 160                 self._lxml = soup_parse(self.html, features='html.parser')
#     161             except ValueError:
#     162                 self._lxml = lxml.html.fromstring(self.raw_html)
#
# ~/anaconda3/lib/python3.6/site-packages/lxml/html/soupparser.py in fromstring(data, beautifulsoup, makeelement, **bsargs)
#      31     used.
#      32     """
# ---> 33     return _parse(data, beautifulsoup, makeelement, **bsargs)
#      34
#      35
#
# ~/anaconda3/lib/python3.6/site-packages/lxml/html/soupparser.py in _parse(source, beautifulsoup, makeelement, **bsargs)
#      77             bsargs['features'] = 'html.parser'  # use Python html parser
#      78     tree = beautifulsoup(source, **bsargs)
# ---> 79     root = _convert_tree(tree, makeelement)
#      80     # from ET: wrap the document in a html root element, if necessary
#      81     if len(root) == 1 and root[0].tag == "html":
#
# ~/anaconda3/lib/python3.6/site-packages/lxml/html/soupparser.py in _convert_tree(beautiful_soup_tree, makeelement)
#     150
#     151     # Process pre_root
# --> 152     res_root = convert_node(html_root)
#     153     prev = res_root
#     154     for e in reversed(pre_root):
#
# ~/anaconda3/lib/python3.6/site-packages/lxml/html/soupparser.py in convert_node(bs_node, parent)
#     214         if handler is None:
#     215             return None
# --> 216         return handler(bs_node, parent)
#     217
#     218     def map_attrs(bs_attrs):
#
# ~/anaconda3/lib/python3.6/site-packages/lxml/html/soupparser.py in convert_tag(bs_node, parent)
#     253             else:
#     254                 if handler is not None:
# --> 255                     handler(child, res)
#     256                 continue
#     257             convert_node(child, res)
#
# ~/anaconda3/lib/python3.6/site-packages/lxml/html/soupparser.py in convert_tag(bs_node, parent)
#     253             else:
#     254                 if handler is not None:
# --> 255                     handler(child, res)
#     256                 continue
#     257             convert_node(child, res)
#
# ~/anaconda3/lib/python3.6/site-packages/lxml/html/soupparser.py in convert_tag(bs_node, parent)
#     253             else:
#     254                 if handler is not None:
# --> 255                     handler(child, res)
#     256                 continue
#     257             convert_node(child, res)
#
# ~/anaconda3/lib/python3.6/site-packages/lxml/html/soupparser.py in convert_text(bs_node, parent)
#     279     def convert_text(bs_node, parent):
#     280         if parent is not None:
# --> 281             append_text(parent, unescape(bs_node))
#     282         return None
#     283
#
# ~/anaconda3/lib/python3.6/site-packages/lxml/html/soupparser.py in append_text(parent, text)
#     231             parent.text = (parent.text or '') + text
#     232         else:
# --> 233             parent[-1].tail = (parent[-1].tail or '') + text
#     234
#     235     # converters are tried in order of their definition
#
# KeyboardInterrupt:

# %%
data = requests.get(INITIAL_QUERY).json()

# %%
_print_data(data)   #check wheather the html format.

# %%
def main():
    data = requests.get(INITIAL_QUERY).json() #In case the JSON decoding fails, r.json() raises an exception
    _print_data(data)
    code = data["continue"]["cmcontinue"]     # next page's number 
    """ <example>
    continue":{"cmcontinue":"page|414245494c4c45204d4552450a414245494c4c45204dc3885245|6478110","continue":"-||"}
    """ 
    next_query = CONTINUE_TEMPLATE.substitute(cmcontinue=code)
    while True:
        
        data = requests.get(next_query).json()
        _print_data(data)
        # Then this is the last one.
        
        if not "continue" in data:
            break
        code = data["continue"]["cmcontinue"]    #assign a new next page's number to code
        next_query = CONTINUE_TEMPLATE.substitute(cmcontinue=code)
        
if __name__ == "__main__":
    main()
